# %% [markdown]
# <a href="https://colab.research.google.com/github/vpkrishna/nlp/blob/main/Project_sec_qa_industry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set-up

# %%
# !pip install dspy-ai
# Out:
# Requirement already satisfied: dspy-ai in /usr/local/lib/python3.10/dist-packages (2.4.5)
# Requirement already satisfied: backoff~=2.2.1 in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (2.2.1)
# Requirement already satisfied: joblib~=1.3.2 in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (1.3.2)
# Requirement already satisfied: openai<2.0.0,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (1.19.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (2.0.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (2023.12.25)
# Requirement already satisfied: ujson in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (5.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (4.66.2)
# Requirement already satisfied: datasets<3.0.0,~=2.14.6 in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (2.14.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (2.31.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (3.6.1)
# Requirement already satisfied: pydantic==2.5.0 in /usr/local/lib/python3.10/dist-packages (from dspy-ai) (2.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.5.0->dspy-ai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.1 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.5.0->dspy-ai) (2.14.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic==2.5.0->dspy-ai) (4.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (1.25.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (3.9.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,~=2.14.6->dspy-ai) (6.0.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.28.1->dspy-ai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=0.28.1->dspy-ai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.28.1->dspy-ai) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=0.28.1->dspy-ai) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dspy-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dspy-ai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dspy-ai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dspy-ai) (2024.2.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna->dspy-ai) (1.13.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna->dspy-ai) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->dspy-ai) (2.0.29)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->dspy-ai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->dspy-ai) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->dspy-ai) (2024.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->dspy-ai) (1.3.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=0.28.1->dspy-ai) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,~=2.14.6->dspy-ai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,~=2.14.6->dspy-ai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,~=2.14.6->dspy-ai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,~=2.14.6->dspy-ai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,~=2.14.6->dspy-ai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,~=2.14.6->dspy-ai) (4.0.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=0.28.1->dspy-ai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=0.28.1->dspy-ai) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets<3.0.0,~=2.14.6->dspy-ai) (3.13.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->dspy-ai) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->dspy-ai) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna->dspy-ai) (2.1.5)

# %%
#from datasets import load_dataset
import openai
import os
import dspy

# %% [markdown]
# Save the API keys in a `.env` file in the local root directory as follows. Then, `load_dotenv()` will make them available to the notebook:

# %%
lm = dspy.OpenAI(model='gpt-3.5-turbo', api_key='jaisrikrishna')
colbert_server = 'http://index.contextual.ai:8893/api/search'
rm = dspy.ColBERTv2(url=colbert_server)
dspy.settings.configure(lm=lm, rm=rm)

# %%
import dspy

class GenerateThemeIndustry(dspy.Signature):
    """
     Your task is to Generate  seven to fifteen sub-industries that give
     exposure to companies associated with the investment theme provided in context.
     Please use the context to  generate the  sub-industries"""
    context = dspy.InputField()
    question=dspy.InputField()
    industries = dspy.OutputField(desc="A comma separated list of seven to fifteen Sub-industries associated with context")

class GenerateThemekeywords(dspy.Signature):
    """
     Your task is to Generate five to ten  keyword associated with the industry given the investment theme in the context.
    The number of keywords must not exceed 10"""
    context = dspy.InputField()
    industry=dspy.InputField()
    keyword = dspy.OutputField(desc="five to ten semantic keywords associated with the each sub-industry")

def convert_to_list(s):
    # Check if the string contains numbered list items
    if '\n' in s and s[1] == '.':
        # Split the string into lines and remove the first three characters from each line
        return [item[3:] for item in s.split('\n') if item[3:] != '']
    else:
        # Split the string by comma
        return [item.strip() for item in s.split(',')]

class ThemeToIndustry(dspy.Module):
    def __init__(self):
        super().__init__()
        # Define the predictor to implement the GenerateThemeIndustry signature.
        self.generate_industry = dspy.ChainOfThought(GenerateThemeIndustry)
        self.generate_keywords = dspy.ChainOfThought(GenerateThemekeywords)

    def forward(self, context, question):
        # Generate sub-industries and their associated bag of key-words
        sub_industries = self.generate_industry(context=context,question=question)
        subindustries=convert_to_list(sub_industries.industries)
        keywords_list=[]
        for sub_industry in subindustries:
            new_keywords = self.generate_keywords(context=context,industry=sub_industry)
            keywordslist=convert_to_list(new_keywords.keyword)
            keywords_list.extend(keywordslist)
        return dspy.Prediction(industries=subindustries,keywords=keywords_list)

# %%
my_question = "Generate seven to fifteen sub-industries that give exposure\
                          to companies associated with the investment theme provided in context"
context='Aerospace & Defence'
theme_pred = ThemeToIndustry()(context=context,question=my_question)
print(theme_pred.industries)
print(theme_pred.keywords)
# Out:
# ['Aircraft manufacturing', 'Defense electronics', 'Aerospace components', 'Military vehicles', 'Space exploration', 'Defense contractors', 'Cybersecurity for defense', 'Satellite technology', 'Unmanned aerial vehicles (drones)', ' Air traffic control systems', ' Defense logistics', ' Missile defense systems', ' Military training and simulation', ' Defense consulting services', ' Aerospace engineering and design']
# ['Aircraft design', 'Composite materials', 'Aviation regulations', 'Market demand', 'Supply chain management', 'Engine technology', 'Defense contracts', 'Maintenance, repair, and overhaul (MRO)', 'Aerospace engineering', ' Innovation in aviation', 'Radar systems', 'Communication systems', 'Electronic warfare', 'Surveillance technology', 'Missile guidance systems', 'Cybersecurity', 'Defense contractors', 'Military electronics', 'Signal processing', ' Avionics', 'Aircraft engines', 'Avionics systems', 'Composite materials', 'Precision machining', 'Aerospace fasteners', 'Hydraulic systems', 'Landing gear components', 'Structural components', 'Electrical systems', ' Flight control systems', 'Armored vehicles', 'Tanks', 'Infantry fighting vehicles', 'Military trucks', 'Amphibious vehicles', 'Reconnaissance vehicles', 'Mine-resistant ambush protected (MRAP) vehicles', 'Self-propelled artillery', 'Armored personnel carriers', ' Light utility vehicles', 'Satellite technology', 'Rocket propulsion', 'Lunar missions', 'Mars colonization', 'Space tourism', 'International Space Station', 'Space debris management', 'Asteroid mining', 'Space telescopes', ' Space habitats', 'Military technology', 'Government contracts', 'National security', 'Aerospace systems', 'Defense industry', 'Military equipment', 'Cybersecurity', 'Intelligence services', 'Strategic partnerships', ' Defense spending', 'Military-grade encryption', 'Threat intelligence', 'Secure communication', 'Network security', 'Cyber warfare', 'Defense systems protection', 'Vulnerability assessment', 'Incident response', 'Secure data storage', ' Advanced persistent threats', 'Satellite communication', 'Earth observation', 'Remote sensing', 'Satellite navigation', 'Satellite manufacturing', 'Space exploration', 'Satellite launch services', 'Satellite data analytics', 'Satellite imagery', ' Satellite technology advancements', 'UAV technology', 'Drone applications', 'Regulatory framework', 'Military drones', 'Commercial drones', 'Autonomous flight', 'Surveillance drones', 'Drone delivery', 'Precision agriculture', ' Drone market trends', 'Radar systems', 'Communication systems', 'Navigation systems', 'Surveillance technology', 'Automation in air traffic control', 'Flight data processing', 'Airspace management', 'Traffic flow management', 'Safety regulations', ' Airport operations', 'Military transportation', 'Supply chain security', 'Defense inventory management', 'Strategic distribution', 'Logistics optimization', 'Defense procurement', 'Military warehousing', 'Asset tracking', 'Defense supply chain', ' Logistics technology', 'Ballistic missiles', 'Interceptor missiles', 'Radar systems', 'Anti-missile technology', 'Missile defense budget', 'Strategic defense', 'Missile defense shield', 'Threat assessment', 'National security', ' Missile defense strategy', 'Virtual reality training', 'Simulation software', 'Tactical training', 'Military simulation', 'Combat readiness', 'Live-fire exercises', 'Mission planning', 'Simulation technology', 'Defense training systems', ' War gaming', 'Strategic planning', 'Risk assessment', 'Cybersecurity', 'Government contracts', 'Military technology', 'Intelligence analysis', 'Training programs', 'Crisis management', 'International relations', ' Defense policy', 'Aircraft design', 'Aerodynamics', 'Structural analysis', 'Avionics', 'Materials science', 'Propulsion systems', 'Flight testing', 'Systems integration', 'Aerospace manufacturing', ' Space exploration']

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/2Stanford/2nlp/Hybrid_Mkt_GPT_4_Theme_Industry_Keywords.csv')
trainsets = []
df_grouped = df.groupby('Theme_Name').agg({
    'Sub_Industry': ', '.join,
    'Keywords': ', '.join
}).reset_index()
for _, row in df_grouped.iterrows():
    context = f"Given the context as {row['Theme_Name']}"
    question = "Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context"

    industries = row['Sub_Industry']
    keyword = row['Keywords']
    example = dspy.Example(context=context, question=question, industries=industries, keyword=keyword).with_inputs('context','question')
    trainsets.append(example)

# %%
trainset=trainsets[0:19]
ootset=trainsets[19:]

# %%
len(ootset)
# Out:
# 6

# %%
df_grouped
# Out:
#                                     Theme_Name  \
# 0                          Aerospace & Defence
# 1                             Aging Population
# 2             Autonomous Technology & Robotics
# 3                                Biotechnology
# 4                          Blockchain and Tech
# 5                                 Clean Energy
# 6                              Cloud Computing
# 7                                Cybersecurity
# 8   Data Center REITs & Digital Infrastructure
# 9                           Fintech Innovation
# 10                          Genomic Revolution
# 11                    Genomics & Biotechnology
# 12                                    Hydrogen
# 13                          Internet of Things
# 14                      Lithium & Battery Tech
# 15                            Medical Devices
# 16                    Next Generation Internet
# 17                  Renewable Energy Producers
# 18        Robotics and Artificial Intelligence
# 19                               Semiconductor
# 20                                       Solar
# 21              Space Exploration & Innovation
# 22               Telemedicine & Digital Health
# 23                      Video Games & Esports
# 24                                 Wind Energy
#
#                                          Sub_Industry  \
# 0   Commercial Aircraft Manufacturing, Military Ai...
# 1   Senior Healthcare Services, Assisted Living Fa...
# 2   Autonomous Transportation, Robotics and Automa...
# 3   Pharmaceutical Biotechnology, Agricultural Bio...
# 4   Cryptocurrency Exchanges, Blockchain Developme...
# 5   Solar Power Generation, Wind Power Generation,...
# 6   Infrastructure-as-a-Service (IaaS), Platform-a...
# 7   Network Security, Endpoint Security, Identity ...
# 8   Data Center Real Estate Investment Trusts (REI...
# 9   Transaction Innovations, Blockchain Technology...
# 10  CRISPR, Targeted Therapeutics, Bioinformatics,...
# 11  Gene Editing and CRISPR, Genomic Sequencing, G...
# 12  Hydrogen Production and Generation, Hydrogen S...
# 13  IoT Devices and Sensors, IoT Connectivity Solu...
# 14  Lithium Mining and Extraction, Battery Materia...
# 15  Diagnostic Equipment, Therapeutic Devices, Pat...
# 16  Cloud Computing & Cyber Security, E-Commerce, ...
# 17  Wind Energy Production, Solar Energy Productio...
# 18  Industrial Automation Robotics, AI Software an...
# 19  Semiconductor Fabrication, Semiconductor Desig...
# 20  Solar Photovoltaic (PV) Manufacturing, Solar P...
# 21  Orbital Aerospace, Suborbital Aerospace, Enabl...
# 22  Telemedicine Services, Health Care Analytics, ...
# 23  Game Development and Publishing, Esports Leagu...
# 24  Wind Turbine Manufacturing, Wind Farm Developm...
#
#                                              Keywords
# 0   airliners, passenger jets, cargo planes, aeros...
# 1   geriatric care, home healthcare, telehealth se...
# 2   self-driving cars, autonomous vehicles, electr...
# 3   drug discovery, therapeutic proteins, monoclon...
# 4   cryptocurrency trading, exchange platform, dig...
# 5   photovoltaic systems, solar panels, solar farm...
# 6   virtual servers, cloud storage, network infras...
# 7   intrusion detection systems, firewalls, virtua...
# 8   data center leasing, colocation services, data...
# 9   payment processing, digital wallets, contactle...
# 10  gene editing, genetic engineering, CRISPR-Cas9...
# 11  CRISPR-Cas9, gene therapy, genome editing, tar...
# 12  electrolysis, steam methane reforming, green h...
# 13  smart sensors, wearables, home automation devi...
# 14  lithium mines, brine extraction, hard rock min...
# 15  imaging systems, MRI, CT scans, X-rays, ultras...
# 16  cloud infrastructure, SaaS, PaaS, IaaS, cybers...
# 17  wind farms, turbines, offshore wind, wind powe...
# 18  industrial robots, automation solutions, manuf...
# 19  foundry services, chip manufacturing, wafer pr...
# 20  solar panels, photovoltaic cells, silicon wafe...
# 21  satellite communications, space station, orbit...
# 22  virtual consultations, remote patient monitori...
# 23  game design, game engines, indie games, AAA ti...
# 24  turbine design, blade manufacturing, nacelle a...

# %%
import json

data = []

# Iterate over the DataFrame
for i, row in df_grouped.iterrows():
    formatted_data = {
        'messages': [
            {'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries\
                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'},
            {'role': 'user', 'content': f'The chosen context is {row["Theme_Name"]}.'},
            {'role': 'assistant', 'content': f'The sub-industries are {row["Sub_Industry"]}. The keywords are {row["Keywords"]}.'}
        ]
    }

    # Add the formatted data to the list
    data.append(formatted_data)

# Split the data into training and validation sets
training_data = data[:10]
validation_data = data[10:15]
oot_data=data[15:]

# %%
import json

data = []

# Iterate over the DataFrame
for i, row in df_grouped.iterrows():
    formatted_data = {
        'messages': [
            {'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries\
                                         generated must not be more than 10. Also generate keywords for the generated sub-industries. I want the answer \
                to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'},
            {'role': 'user', 'content': f'The chosen context is {row["Theme_Name"]}.'},
            {'role': 'assistant', 'content': f'The sub-industries are {row["Sub_Industry"]}. The keywords are {row["Keywords"]}.'}
        ]
    }

    # Add the formatted data to the list
    data.append(formatted_data)

oot_data_untrained=data[19:]

# %%
import json

training_file_name = "training_data.jsonl"
validation_file_name = "validation_data.jsonl"
oot_file_name="oot_data.jsonl"
oot_untrained_file_name="oot_data_untrained.jsonl"

def prepare_data(dictionary_data, final_file_name):
    with open(final_file_name, 'w') as outfile:
        for entry in dictionary_data:
        	json.dump(entry, outfile)
        	outfile.write('\n')

prepare_data(training_data, "training_data.jsonl")
prepare_data(validation_data, "validation_data.jsonl")
prepare_data(oot_data, "oot_data.jsonl")
prepare_data(oot_data_untrained, "oot_data_untrained.jsonl")

# %%
def load_jsonl(input_path):
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.strip()))
    return data

# Load the data
training_data = load_jsonl("training_data.jsonl")

# Now, you can print the data
for entry in training_data:
    print(entry)
# Out:
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Aerospace & Defence.'}, {'role': 'assistant', 'content': 'The sub-industries are Commercial Aircraft Manufacturing, Military Aircraft and Systems, Space Systems and Exploration, Defense Equipment and Armaments, Aerospace Components and Systems, Unmanned Aerial Vehicles (UAVs), Aerospace Maintenance and Services. The keywords are airliners, passenger jets, cargo planes, aerospace engineering, aviation technology, assembly lines, fighter jets, military drones, surveillance aircraft, missile systems, defense electronics, tactical aircraft, satellites, space probes, launch vehicles, space stations, lunar exploration, Mars missions, armored vehicles, naval ships, submarines, artillery systems, smart munitions, electronic warfare, avionics, propulsion systems, flight control systems, landing gear, aerospace materials, composite structures, drones, UAV systems, autonomous flight, surveillance drones, combat drones, drone navigation, MRO (maintenance, repair, and overhaul), retrofitting, upgrades, flight training, simulation systems, logistic support.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Aging Population.'}, {'role': 'assistant', 'content': 'The sub-industries are Senior Healthcare Services, Assisted Living Facilities, Pharmaceutical Development for Age-Related Diseases, Medical Devices for Seniors, Nutritional Supplements and Health Foods, Financial Services for Seniors, Age-Friendly Products and Services. The keywords are geriatric care, home healthcare, telehealth services, chronic disease management, medical alert systems, gerontology, senior living communities, retirement homes, assisted living services, memory care, long-term care facilities, community wellness, geriatric medicines, age-related therapeutics, dementia treatment, osteoporosis drugs, longevity research, clinical trials, mobility aids, hearing aids, medical wearables, health monitoring devices, orthopedic implants, assistive technology, dietary supplements, senior nutrition, functional foods, age-specific vitamins, nutritional therapy, health supplements, retirement planning, estate planning, wealth management for seniors, annuities, financial advising, elder financial protection, adaptive clothing, age-friendly design, senior transportation services, ergonomic products, home retrofitting services.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Autonomous Technology & Robotics.'}, {'role': 'assistant', 'content': 'The sub-industries are Autonomous Transportation, Robotics and Automation, 3D Printing, Energy Storage, Space Exploration. The keywords are self-driving cars, autonomous vehicles, electric vehicles, drone delivery, smart transportation systems, vehicle telematics, industrial robots, service robots, robotic process automation, artificial intelligence in robotics, collaborative robots, automation software, additive manufacturing, rapid prototyping, 3D printers, printable materials, digital fabrication, custom manufacturing, 3D modeling software, battery technology, lithium-ion batteries, renewable energy storage, grid storage solutions, energy management systems, supercapacitors, spacecraft, space missions, satellite technology, interplanetary exploration, space mining, astronomical research, commercial spaceflight.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Biotechnology.'}, {'role': 'assistant', 'content': 'The sub-industries are Pharmaceutical Biotechnology, Agricultural Biotechnology, Industrial Biotechnology, Environmental Biotechnology, Medical Devices and Diagnostics, Genomics and Proteomics, Bioinformatics and Data Analysis. The keywords are drug discovery, therapeutic proteins, monoclonal antibodies, vaccine development, clinical trials, pharmacogenomics, genetically modified organisms (GMOs), crop yield improvement, biopesticides, plant biotech, agricultural genomics, biofuels, biocatalysis, fermentation technology, biodegradable materials, bio-based chemicals, industrial enzymes, bioremediation, wastewater treatment, biofiltration, environmental monitoring, green technology, waste management, diagnostic tests, medical imaging, regenerative medicine, wearable health technology, lab-on-a-chip, precision medicine, genome sequencing, gene editing (CRISPR), proteomics analysis, bioinformatics, molecular diagnostics, personalized genomics, computational biology, genetic data analysis, systems biology, molecular modeling, next-generation sequencing data, AI in biotech.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Blockchain and Tech.'}, {'role': 'assistant', 'content': 'The sub-industries are Cryptocurrency Exchanges, Blockchain Development Platforms, Decentralized Finance (DeFi), Digital Asset Management, Smart Contract Services, Blockchain in Supply Chain, Crypto Mining Infrastructure. The keywords are cryptocurrency trading, exchange platform, digital wallets, liquidity services, order matching, security protocols, transaction processing, smart contracts, blockchain protocols, distributed applications (dApps), development frameworks, API services, consensus mechanisms, decentralized exchanges (DEX), lending protocols, staking, governance tokens, decentralized autonomous organizations (DAOs), DeFi applications, tokenization, digital asset custody, blockchain-based asset tracking, investment tokens, portfolio management on blockchain, contract development, audit and compliance, on-chain verification, decentralized oracles, Ethereum, chainlink, product traceability, anti-counterfeit measures, logistics optimization, real-time data, supply chain finance, blockchain-enabled provenance, mining hardware, hash power, mining pools, energy consumption, mining algorithms, Proof of Work, Proof of Stake.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Clean Energy.'}, {'role': 'assistant', 'content': 'The sub-industries are Solar Power Generation, Wind Power Generation, Hydroelectric Power, Biomass Energy, Geothermal Energy, Tidal and Wave Energy, Energy Storage Solutions. The keywords are photovoltaic systems, solar panels, solar farms, concentrated solar power, residential solar solutions, wind turbines, offshore wind farms, wind energy technology, wind resource assessment, wind power plants, hydro plants, dam technology, run-of-river systems, pumped-storage hydroelectricity, micro-hydro systems, biofuels, biopower, anaerobic digestion, biomass to electricity, sustainable biomass, geothermal power stations, heat pumps, geothermal drilling, enhanced geothermal systems, tidal barrages, wave energy converters, ocean energy systems, marine current power, battery storage, thermal storage, pumped hydro storage, flywheel energy storage, grid-scale energy storage.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Cloud Computing.'}, {'role': 'assistant', 'content': 'The sub-industries are Infrastructure-as-a-Service (IaaS), Platform-as-a-Service (PaaS), Software-as-a-Service (SaaS), Data Center REITs, Cloud Security and Compliance, Edge Computing. The keywords are virtual servers, cloud storage, network infrastructure, scalable computing resources, disaster recovery, on-demand computing, development tools, application hosting, database management, business analytics, middleware, application development platforms, cloud applications, subscription software, CRM, ERP, collaboration tools, office suites, customer service software, data center leasing, colocation services, data center real estate, interconnection services, cloud data center facilities, identity management, cloud access security, data privacy, regulatory compliance, security assessment, encryption services, distributed computing, edge devices, real-time data processing, latency reduction, edge data centers, IoT edge solutions.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Cybersecurity.'}, {'role': 'assistant', 'content': 'The sub-industries are Network Security, Endpoint Security, Identity and Access Management, Cloud Security, Data Security and Encryption, Threat Intelligence and Response, Application Security. The keywords are intrusion detection systems, firewalls, virtual private networks (VPNs), network monitoring, security operations centers (SOCs), antivirus software, anti-malware, endpoint protection platforms (EPP), mobile device security, endpoint detection and response (EDR), single sign-on (SSO), multi-factor authentication (MFA), identity verification, access controls, user behavior analytics, cloud access security brokers (CASBs), secure web gateways, cloud workload protection, encryption in transit and at rest, data loss prevention (DLP), encryption algorithms, tokenization, database security, secure data storage solutions, security information and event management (SIEM), threat hunting, incident response, cyber threat intelligence platforms, application firewalls, secure coding practices, application security testing, software composition analysis.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Data Center REITs & Digital Infrastructure.'}, {'role': 'assistant', 'content': 'The sub-industries are Data Center Real Estate Investment Trusts (REITs), Network Infrastructure Providers, Cloud Data Centers, Edge Data Centers, Digital Infrastructure Services, Connectivity Solutions, Data Center Design and Construction. The keywords are data center leasing, colocation services, data center operations, real estate portfolio, interconnection ecosystems, fiber optic networks, bandwidth management, telecommunications infrastructure, network as a service (NaaS), backbone networks, cloud hosting services, managed services, Infrastructure-as-a-Service (IaaS), data storage solutions, on-demand computing resources, edge computing facilities, latency optimization, content delivery networks, edge server locations, distributed computing architecture, network support services, infrastructure management, IT support, virtual infrastructure, systems integration, broadband services, wireless infrastructure, internet exchange points, connectivity products, high-speed internet access, data center architecture, modular data centers, cooling solutions, power efficiency, green data centers.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.The sub-industries                                         generated must not be more than 10. Also generate keywords for the generated sub-industries'}, {'role': 'user', 'content': 'The chosen context is Fintech Innovation.'}, {'role': 'assistant', 'content': 'The sub-industries are Transaction Innovations, Blockchain Technology, Risk Transformation, Frictionless Funding Platforms, Customer Facing Platforms, New Intermediaries. The keywords are payment processing, digital wallets, contactless payments, mobile payments, real-time transactions, cross-border payments, P2P payments, distributed ledger technology, blockchain platforms, smart contracts, tokenization, decentralized applications, crypto assets, blockchain security, risk management, regulatory technology, compliance automation, fraud detection, credit risk, cyber risk, insurtech, crowdfunding, peer-to-peer lending, microfinancing, investment platforms, robo-advisors, financial automation, seamless transactions, personal finance management, customer engagement, digital banking, mobile banking, financial planning tools, chatbots, AI customer service, financial marketplaces, comparison platforms, API banking, Banking-as-a-Service, platform banking, disintermediation, open banking.'}]}

# %%
import os
from openai import OpenAI

openai.api_key='jaisrikrishna'
client = OpenAI(api_key='Harisarvothama')

# %%
from pathlib import Path
from openai import OpenAI

# Define the paths to your training and validation data files
training_file_path = Path('/content/training_data.jsonl')
validation_file_path = Path('/content/validation_data.jsonl')

training_response = client.files.create(
    file=training_file_path,
    purpose='fine-tune',
)

# Get the file ID from the response
training_file_id = training_response.id

# Upload the validation data
validation_response = client.files.create(
    file=validation_file_path,
    purpose='fine-tune',
)

# Get the file ID from the response
validation_file_id = validation_response.id

# Print the file IDs
print('Training file id:', training_file_id)
print('Validation file id:', validation_file_id)
# Out:
# Training file id: file-Rvo6yDcKZCby71udM7G9OdDP
# Validation file id: file-sq3o1xClFf2MXdmkgExZTtpS

# %%
training_response
# Out:
# FileObject(id='file-Rvo6yDcKZCby71udM7G9OdDP', bytes=14617, created_at=1713249064, filename='training_data.jsonl', object='file', purpose='fine-tune', status='processed', status_details=None)

# %%
untrained_model="gpt-3.5-turbo"

# %%
response = client.fine_tuning.jobs.create(
  training_file=training_file_id,
  validation_file=validation_file_id,
  model="gpt-3.5-turbo",
)
job_id = response.id
status = response.status

print(f'Fine-tunning model with jobID: {job_id}.')
print(f"Training Response: {response}")
print(f"Training Status: {status}")
# Out:
# Fine-tunning model with jobID: ftjob-oHoakXA5i7MibqG4ijiIPvLy.
# Training Response: FineTuningJob(id='ftjob-oHoakXA5i7MibqG4ijiIPvLy', created_at=1713249074, error=Error(code=None, message=None, param=None, error=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-nOf04gzKve7yBkytwqAAom71', result_files=[], seed=1013993064, status='validating_files', trained_tokens=None, training_file='file-Rvo6yDcKZCby71udM7G9OdDP', validation_file='file-sq3o1xClFf2MXdmkgExZTtpS', integrations=[], user_provided_suffix=None)
# Training Status: validating_files

# %%
import time

status = client.fine_tuning.jobs.retrieve(job_id).status
if status not in ["succeeded", "failed"]:
    print(f"Job not in terminal status: {status}. Waiting.")
    while status not in ["succeeded", "failed"]:
        time.sleep(2)
        status = client.fine_tuning.jobs.retrieve(job_id).status
        print(f"Status: {status}")
else:
    print(f"Finetune job {job_id} finished with status: {status}")
print("Checking other finetune jobs in the subscription.")
result = client.fine_tuning.jobs.list()
print(f"Found {len(result.data)} finetune jobs.")
# Out:
# Job not in terminal status: validating_files. Waiting.
# Status: validating_files
# Status: validating_files
# Status: validating_files
# Status: validating_files
# Status: validating_files
# Status: validating_files
# Status: validating_files
# Status: validating_files
# Status: queued
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: running
# Status: succeeded
# Checking other finetune jobs in the subscription.
# Found 13 finetune jobs.

# %%
# Retrieve the finetuned model
fine_tuned_model = result.data[0].fine_tuned_model
print(fine_tuned_model)
# Out:
# ft:gpt-3.5-turbo-0125:personal::9EWmoAX1

# %%
# fine_tuned_model="ft:gpt-3.5-turbo-0125:personal::9ETXqOlY"

# %%
completion = client.chat.completions.create(
  model=fine_tuned_model,
  messages=[
    {'role': 'system',
    'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.'},
   {'role': 'user', 'content': 'The chosen context is Aerospace & Defence.'}
  ],temperature=0, max_tokens=500
)
print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The sub-industries are Commercial Aircraft Manufacturing, Military Aircraft and Systems, Space Systems and Exploration, Defense Equipment and Armaments, Aerospace Components and Systems, Unmanned Aerial Vehicles (UAVs), Aerospace Maintenance and Services.', role='assistant', function_call=None, tool_calls=None)

# %%
test_messages=  messages=[
    {'role': 'system','content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context.'},
   {'role': 'user', 'content': 'The chosen context is Large Language Models.'}
  ]

# %%
response = client.chat.completions.create(
    model=fine_tuned_model,
    messages=test_messages,
    temperature=0, max_tokens=500
)
print(response.choices[0].message)
# Out:
# ChatCompletionMessage(content='The sub-industries are Natural Language Processing (NLP), Machine Learning, Deep Learning, Data Labeling and Annotation, Text-to-Speech, Speech Recognition, Language Generation Models, Conversational AI.', role='assistant', function_call=None, tool_calls=None)

# %%
model="gpt-3.5-turbo"
completion = client.chat.completions.create(
  model=model,
  messages=[
    {'role': 'system',
    'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer \
                to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords'},
   {'role': 'user', 'content': 'The chosen context is Aerospace & Defence.'}
  ]
)
print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='The sub-industries are:\n1. Commercial Aerospace\n2. Military Aerospace\n3. Aerospace Components\n4. Defense Contractors\n5. Cybersecurity for Defense\n6. Space Exploration\n7. Unmanned Aerial Vehicles (UAVs)\n8. Aerospace Maintenance, Repair, and Overhaul (MRO)\n  \nThe keywords are:\n1. Aerospace industry\n2. Defense sector\n3. Fighter jets\n4. Space technology\n5. Military contracts', role='assistant', function_call=None, tool_calls=None)

# %%
def load_jsonl(input_path):
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.strip()))
    return data

# Load the data
oot_data_untrained = load_jsonl("oot_data_untrained.jsonl")

# Now, you can print the data
for entry in oot_data_untrained:
    print(entry)
# Out:
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer                 to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'}, {'role': 'user', 'content': 'The chosen context is Semiconductor.'}, {'role': 'assistant', 'content': 'The sub-industries are Semiconductor Fabrication, Semiconductor Design, Semiconductor Equipment and Materials, Microprocessors and Chipsets, Memory and Storage Technology, Semiconductor Distribution, Advanced Semiconductor Technologies. The keywords are foundry services, chip manufacturing, wafer processing, photolithography, cleanroom technology, semiconductor fabrication plants, integrated circuit design, CAD for electronics, microarchitecture, system-on-chip (SoC), electronic design automation (EDA), semiconductor machinery, fabrication equipment, testing equipment, silicon wafers, chemicals and gases for semiconductor production, CPU design, graphics processors, chipsets, performance computing, central processing units, mobile processors, DRAM, SSDs, flash memory, memory chips, non-volatile memory, data storage solutions, supply chain logistics, electronic component distribution, B2B semiconductor sales, inventory management, nanoelectronics, quantum dots, semiconductor lasers, power semiconductors, high-electron-mobility transistors.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer                 to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'}, {'role': 'user', 'content': 'The chosen context is Solar.'}, {'role': 'assistant', 'content': 'The sub-industries are Solar Photovoltaic (PV) Manufacturing, Solar Power Generation, Solar Energy Storage Solutions, Solar Thermal Technology, Solar Products and Applications, Integration of Solar into Energy Systems, Research and Development in Solar Technology. The keywords are solar panels, photovoltaic cells, silicon wafers, thin-film solar cells, solar module assembly, efficiency improvements, solar farms, rooftop solar installations, utility-scale solar, solar power plants, feed-in tariffs, power purchase agreements (PPAs), solar batteries, energy storage systems, grid integration, charge controllers, off-grid solar solutions, solar water heating, concentrated solar power (CSP), solar thermal collectors, parabolic troughs, solar towers, solar lighting, portable solar chargers, solar-powered appliances, building-integrated photovoltaics (BIPV), smart grids, net metering, microgrids, renewable energy integration, solar energy management systems, next-generation photovoltaics, perovskite solar cells, organic photovoltaic cells (OPVs), solar efficiency research, innovative solar materials.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer                 to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'}, {'role': 'user', 'content': 'The chosen context is Space Exploration & Innovation.'}, {'role': 'assistant', 'content': 'The sub-industries are Orbital Aerospace, Suborbital Aerospace, Enabling Technologies, Aerospace Beneficiary. The keywords are satellite communications, space station, orbital launch vehicles, satellite manufacturing, space exploration, space tourism, earth observation, suborbital flights, space tourism, research platforms, suborbital transportation, reusable launch vehicles, rocket propulsion, space-grade materials, aerospace engineering, navigation technology, life support systems, space suits, avionics, terrestrial networks, space-based internet, space law, remote sensing, global positioning system, space-based research, aerospace investment.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer                 to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'}, {'role': 'user', 'content': 'The chosen context is Telemedicine & Digital Health.'}, {'role': 'assistant', 'content': 'The sub-industries are Telemedicine Services, Health Care Analytics, Connected Health Care Devices, Administrative Digitization, Digital Therapeutics, Mobile Health Applications, Health Data Security. The keywords are virtual consultations, remote patient monitoring, telehealth platforms, e-prescriptions, video conferencing healthcare, online medical services, big data in healthcare, predictive analytics, health informatics, electronic health records (EHR), clinical decision support, patient data analysis, wearable health monitors, IoT medical devices, smart health devices, remote diagnostic equipment, health tracking apps, medical billing automation, health care IT solutions, electronic medical records (EMR) systems, practice management software, health care administration, software as a medical device, app-based health interventions, digital treatment platforms, cognitive behavioral therapy apps, mHealth apps, fitness tracking, lifestyle management apps, medication adherence apps, patient engagement applications, health data encryption, HIPAA-compliant platforms, cybersecurity in healthcare, patient privacy technology, secure health data exchange.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer                 to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'}, {'role': 'user', 'content': 'The chosen context is Video Games & Esports .'}, {'role': 'assistant', 'content': 'The sub-industries are Game Development and Publishing, Esports Leagues and Competitions, Gaming Platforms and Services, Gaming Hardware and Accessories, Virtual and Augmented Reality Gaming, Content Creation and Streaming, Game Analytics and User Engagement. The keywords are game design, game engines, indie games, AAA titles, mobile gaming, cross-platform development, competitive gaming, esports tournaments, professional teams, live streaming events, esports arenas, online gaming platforms, digital distribution, game streaming services, multiplayer servers, gaming communities, gaming consoles, PC gaming rigs, gaming peripherals, VR headsets, custom controllers, high-performance hardware, VR gaming experiences, AR mobile games, immersive technology, mixed reality, VR content development, game streaming, content creators, live game broadcasts, video game vlogging, streaming platforms, player data analysis, gaming trends, user experience research, engagement metrics, in-game advertising.'}]}
# {'messages': [{'role': 'system', 'content': 'Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context. I want the answer                 to be written as The sub-industries are and then sub_industries.Likewise for keywords, I want the answer as The keywords are and then keywords.'}, {'role': 'user', 'content': 'The chosen context is Wind Energy.'}, {'role': 'assistant', 'content': 'The sub-industries are Wind Turbine Manufacturing, Wind Farm Development and Operation, Wind Energy Storage Solutions, Offshore Wind Energy, Wind Energy Infrastructure, Advanced Wind Technologies, Wind Energy Consulting and Services. The keywords are turbine design, blade manufacturing, nacelle assembly, offshore turbines, onshore wind turbines, turbine components, site assessment, wind farm construction, project management, operations and maintenance, wind power generation, battery storage, grid integration, energy management systems, power-to-grid solutions, storage technology, offshore wind farms, floating turbines, marine engineering, installation vessels, seabed surveying, electrical infrastructure, substations, transmission lines, grid connection, wind measurement systems, vertical axis turbines, wind energy software, performance optimization, aerodynamics analysis, remote sensing technologies, feasibility studies, environmental impact assessments, wind resource analysis, technical advisory, project financing.'}]}

# %%
fine_tuned_model
# Out:
# 'ft:gpt-3.5-turbo-0125:personal::9E9QxsgD'

# %%
import json
import openai

# Function to load data from a .jsonl file
def load_jsonl(input_path):
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.strip()))
    return data

# Load the data
oot_data = load_jsonl("oot_data.jsonl")
# Combine training and validation data
all_data = oot_data

list_sub_industries=[]
list_keywords=[]
# Iterate over all data
for conversation in all_data:
    # Extract the messages from the conversation
    messages = conversation['messages']
    messages = [message for message in messages if message['role'] != 'assistant']
    response = client.chat.completions.create(
    model=fine_tuned_model,
    messages=messages,
    temperature=0, max_tokens=500)
    response_text = response.choices[0].message.content
    print(response_text)
    # Split the response_text into two parts: sub_industries and keywords
    sub_industries_part, keywords_part = response_text.split(". The keywords are ")
    # Remove the leading phrase from sub_industries_part and split it into a list
    sub_industries_list = sub_industries_part.replace("The sub-industries are ", "").split(", ")
    # Split keywords_part into a list
    keywords_list = keywords_part.split(", ")
    list_sub_industries.append(sub_industries_list)
    list_keywords.append(keywords_list)
# Out:
# The sub-industries are Semiconductor Manufacturing, Semiconductor Equipment and Materials, Integrated Circuit Design, Semiconductor Foundries, LED Semiconductor Devices, Power Semiconductors, Memory Semiconductors, Semiconductor IP and Design Services. The keywords are wafer fabrication, semiconductor devices, integrated circuits, microchips, electronic components, silicon wafers, gallium arsenide, semiconductor packaging, assembly and testing, semiconductor process technology, lithography, etching, deposition, wafer cleaning, thin film deposition, photomask, semiconductor materials, silicon, compound semiconductors, semiconductor nanoparticles, quantum dots, LED chips, solid state lighting, LED displays, optoelectronic devices, semiconductor lasers, photovoltaic cells, power diodes, MOSFETs, IGBTs, power modules, voltage regulators, power management ICs, superconducting power devices, memory chips, DRAM, SRAM, flash memory, non-volatile memory, memory controllers, semiconductor IP cores, electronic design automation, custom IC design, ASICs, FPGAs, semiconductor foundry services, wafer processing, foundry business model, fabless semiconductor companies, semiconductor design IP, EDA software, system-on-chip, integrated circuit design services, custom chip design, ASIC design, FPGA design, electronic design services, semiconductor intellectual property, IP licensing, IP cores, SoC design, semiconductor design verification, design for test, product engineering, semiconductor manufacturing services.
# The sub-industries are Solar Power Generation, Solar Panel Manufacturing, Solar Farm Development, Concentrated Solar Power, Residential Solar Solutions, Commercial and Industrial Solar Solutions, Solar Technology and Innovation. The keywords are photovoltaic systems, solar panels, solar arrays, solar power plants, concentrated photovoltaics, solar thermal, residential solar panels, solar water heaters, solar air conditioners, solar lighting solutions, off-grid solar systems, energy storage solutions, solar installation services, wind and solar hybrid systems, geothermal power, hydroelectric power, biomass energy, tidal and wave energy, energy efficiency, green buildings, sustainable energy technology, solar innovations, space solar power.
# The sub-industries are Launch Services, Satellite Manufacturing, Space Exploration, Space Mining, Space Systems and Components, Space Transportation, Space Stations, Lunar Exploration, Mars Exploration. The keywords are rocket launch, space launch vehicles, satellite launch services, interplanetary missions, space probes, telescopes, observatories, satellite communication, remote sensing, weather forecasting, disaster management, navigation satellites, space station construction, lunar missions, Mars missions, asteroid mining, lunar mining, Mars colonization, space mining equipment, robotic missions, space exploration technology, propulsion systems, spacecraft design, space systems integration, satellite components, space hardware, aerospace engineering, 3D printing in space, in-space manufacturing, space mining resources, asteroid mining, lunar mining, Mars mining, space resource utilization, mining technology, ISRU (in-situ resource utilization), space transportation systems, rockets, space shuttles, launch pads, spaceports, orbital mechanics, space navigation, lunar landers, Mars rovers, space mining robots, robotic arms, autonomous systems, artificial intelligence in space, Mars habitats, space stations, interplanetary spaceflight.
# The sub-industries are Telehealth Services, Remote Patient Monitoring, Digital Health Devices, Medical Robotics, Healthcare Data Analytics, Telemedicine Software Platforms, Chronic Disease Management, Wearable Health Technology, Telehealth Infrastructure. The keywords are virtual doctor visits, teleconsultation, teletriage, remote health monitoring, medical alert systems, telemedicine equipment, wearable health monitors, digital therapeutics, health tracking devices, mobile health solutions, telehealth software, remote patient management, chronic care monitoring, medical wearables, health data management, electronic health records, telemedicine systems, diagnostic tools, medical imaging, regenerative medicine, robotic surgery, tele-robotics, robotic process automation, AI in healthcare, precision medicine, genome sequencing, bioinformatics, health analytics, remote data analysis, real-time health information, predictive analytics, personalized health, telemonitoring, mHealth, wearable technology, health apps, remote physiological monitoring, smart healthcare devices, home healthcare, chronic disease tracking, medical nutrition therapy, telepsychiatry, remote patient counseling, health coaching, teletherapy, mental health support, chronic disease management software, medical device connectivity, health IT systems, telehealth infrastructure, broadband in healthcare, telecommunication systems, remote health services, telehealth support, health data security, regulatory compliance, telemedicine legal issues, privacy protection, data breach prevention.
# The sub-industries are Video Game Development, Game Publishing, Esports Events and Tournaments, Gaming Hardware and Accessories, Esports Teams and Organizations, Game Streaming and Content Creation. The keywords are video game design, game programming, 3D modeling, animation, game engines, virtual reality (VR) games, augmented reality (AR) games, mobile games, console games, PC games, gaming laptops, gaming desktops, virtual currency, in-game purchases, downloadable content (DLC), game distribution, digital rights management (DRM), online gaming, multiplayer games, esports competitions, tournament organization, prize money, sponsorship deals, advertising, esports broadcasting, streaming services, gaming chairs, virtual reality headsets, gaming controllers, hardware upgrades, custom gaming PCs, gaming peripherals, computer monitors, graphics cards, esports leagues, competitive gaming, professional gamers, esports teams, gaming organizations, team sponsorships, esports merchandise, competitive events, gaming conventions, esports industry, game streaming, content creation, online gaming communities, video game journalism, esports media, live streaming, gameplay videos, online content, influencer marketing, virtual events, esports entertainment, gaming tournaments, online sports, skill-based gaming, electronic sports, broadcast rights, streaming technology, content distribution, video game streaming, esports streaming, live esports events, tournament streaming, player streaming, game commentary, esports analysis, spectator sports, sports marketing, esports advertising, brand partnerships, sponsorships, in-game advertising, product placement, advergames, esports team management, player contracts, gaming talent scouting, esports training, coaching, team support, competitive gaming infrastructure, esports data analytics, performance tracking, in-game statistics, player behavior analysis, virtual goods, in-game items, digital gaming content, microtransactions, downloadable games, game subscriptions, online game stores, gaming platform, PC gaming, console gaming, mobile gaming, cross-platform gaming, gaming as a service, cloud gaming, VR gaming, AR gaming, mixed reality gaming, location-based AR, mobile AR, AR glasses, VR headsets, virtual worlds, in-game virtual items, blockchain gaming, NFTs in gaming, tokenized assets, decentralized gaming platforms, esports betting, online gaming revenue, video game monetization, free-to-play games, in-game advertising, esports revenue streams, sponsorship revenue, media rights, advertising revenue, brand exposure, esports audience, gamer demographics, esports fanbase, online gaming community, gaming forums, social gaming, esports market, video game sales,
# The sub-industries are Onshore Wind Power Generation, Offshore Wind Power Generation, Wind Turbine Manufacturing, Wind Resource Assessment and Forecasting, Wind Farm Development, Operations and Maintenance, Wind Power Technology Innovation. The keywords are wind farms, wind turbines, power plants, energy production, electricity generation, renewable energy, clean technology, onshore wind farms, offshore wind farms, wind energy technology, wind resource data, wind monitoring, meteorological towers, data analysis, forecasting models, wind power plants, hydro-wind hybrid systems, solar-wind hybrid systems, geothermal-wind hybrid systems, tidal energy, wave energy, ocean current power, marine energy systems, offshore wind technology, floating wind turbines, wind turbine design, blade technology, offshore wind resource assessment, wind atlas, resource mapping, wind potential analysis, site selection, wind farm layout, infrastructure development, project planning, project finance, wind project management, construction, installation, commissioning, operations, maintenance, retrofitting, upgrades, condition monitoring, smart maintenance, offshore wind farm maintenance, wind energy storage, grid integration, energy management systems, power system stability, ancillary services, wind-diesel integration, community wind power, distributed wind energy, offshore wind resource assessment, wind lidar, wind profiling, remote sensing technology, satellite wind data, weather forecasting, wind prediction, power output forecasting, energy trading, virtual power plants, demand response, grid support services, energy storage solutions, pumped-storage hydroelectricity, battery storage, thermal storage, flywheel energy storage, grid-scale energy storage, energy storage management, supercapacitors, spacecraft power systems, wind propulsion, ocean energy, marine current power, wave energy converters, ocean energy systems, marine current technology, battery management, grid-scale renewables integration, energy storage for wind power, hydro-wind power stations, solar-wind hybrid power stations, geothermal-wind hybrid power stations, tidal barrages, wave energy systems, ocean energy storage, marine energy to electricity, green shipping technology.

# %%
list_sub_industries
# Out:
# [['Semiconductor Manufacturing',
#   'Semiconductor Equipment and Materials',
#   'Integrated Circuit Design',
#   'Semiconductor Foundries',
#   'LED Semiconductor Devices',
#   'Power Semiconductors',
#   'Memory Semiconductors',
#   'Semiconductor IP and Design Services'],
#  ['Solar Power Generation',
#   'Solar Panel Manufacturing',
#   'Solar Farm Development',
#   'Concentrated Solar Power',
#   'Residential Solar Solutions',
#   'Commercial and Industrial Solar Solutions',
#   'Solar Technology and Innovation'],
#  ['Launch Services',
#   'Satellite Manufacturing',
#   'Space Exploration',
#   'Space Mining',
#   'Space Systems and Components',
#   'Space Transportation',
#   'Space Stations',
#   'Lunar Exploration',
#   'Mars Exploration'],
#  ['Telehealth Services',
#   'Remote Patient Monitoring',
#   'Digital Health Devices',
#   'Medical Robotics',
#   'Healthcare Data Analytics',
#   'Telemedicine Software Platforms',
#   'Chronic Disease Management',
#   'Wearable Health Technology',
#   'Telehealth Infrastructure'],
#  ['Video Game Development',
#   'Game Publishing',
#   'Esports Events and Tournaments',
#   'Gaming Hardware and Accessories',
#   'Esports Teams and Organizations',
#   'Game Streaming and Content Creation'],
#  ['Onshore Wind Power Generation',
#   'Offshore Wind Power Generation',
#   'Wind Turbine Manufacturing',
#   'Wind Resource Assessment and Forecasting',
#   'Wind Farm Development',
#   'Operations and Maintenance',
#   'Wind Power Technology Innovation']]

# %%
import json
import openai

# Function to load data from a .jsonl file
def load_jsonl(input_path):
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.strip()))
    return data

# Load the data
oot_data_untrained = load_jsonl("oot_data_untrained.jsonl")


# Combine training and validation data
all_data =oot_data_untrained

list_sub_industries_untrained=[]
list_keywords_untrained=[]
# Iterate over all data
for conversation in all_data:
    # Extract the messages from the conversation
    messages = conversation['messages']
    messages = [message for message in messages if message['role'] != 'assistant']
    response = client.chat.completions.create(
    model=untrained_model,
    messages=messages,
    temperature=0, max_tokens=500)
    response_text = response.choices[0].message.content
    parts = response_text.split('The keywords are:')
    sub_industries_part = parts[0]
    keywords_part = parts[1]
    sub_industries_list=sub_industries_part.replace('The sub-industries are:', '').split('\n')[1:]
    keywords_list = keywords_part.split('\n')[1:]
    sub_industries_list=[item.strip()[3:] for item in sub_industries_list if item.strip()]
    keywords_list= [item.strip()[3:] for item in keywords_list if item.strip()]
    list_sub_industries_untrained.append(sub_industries_list)
    list_keywords_untrained.append(keywords_list)

# %%
df_grouped_copy=df_grouped[19:].copy()
theme_list=df_grouped_copy['Theme_Name'].values.tolist()
df_grouped_copy['Sub_Industry'] = df_grouped_copy['Sub_Industry'].str.split(',').apply(lambda x: [i.strip() for i in x])
industry_list_golden = df_grouped_copy['Sub_Industry'].tolist()
df_grouped_copy['Keywords'] =df_grouped_copy['Keywords'].str.split(',').apply(lambda x: [i.strip() for i in x])
Keywords_list_golden = df_grouped_copy['Keywords'].tolist()

# %%
print(len(list_sub_industries), len(industry_list_golden))
# Out:
# 6 6

# %%
def create_bigrams(lst):
    bigrams = set()
    for sublist in lst:
        for string in sublist:
            words = string.split()
            words=[word.lower().strip() for word in words]
            for i in range(len(words)-1):
                bigrams.add((words[i], words[i+1]))

    return [bigram for bigram in bigrams if 'and' not in bigram and 'for' not in bigram and  'or' not in bigram and 'in' not in bigram]



def compare_bigrams(industry_list, industry_list_golden):
    bigrams_industry = create_bigrams(industry_list)
    bigrams_golden = create_bigrams(industry_list_golden)

    tp = sum(1 for bigram in bigrams_industry if bigram in bigrams_golden)
    fp = sum(1 for bigram in bigrams_industry if bigram not in bigrams_golden)
    fn = sum(1 for bigram in bigrams_golden if bigram not in bigrams_industry)
    return tp, fp, fn , tp/(tp+fp) , tp/(tp+fn)

# %% [markdown]
# ## OOT results

# %%
print(len(list_sub_industries),len(industry_list_golden))
tp, fp, fn ,precision, recall = compare_bigrams(list_sub_industries, industry_list_golden)
print(f"TP: {tp}, FP: {fp}, FN: {fn}, Precision: {precision}, Recall : {recall}")
# Out:
# 6 6
# TP: 12, FP: 52, FN: 46, Precision: 0.1875, Recall : 0.20689655172413793

# %% [markdown]
# ## Untrained model results

# %%
list_sub_industries=list_sub_industries_untrained
industry_list_golden=list_keywords_untrained
print(len(list_sub_industries),len(industry_list_golden))
tp, fp, fn ,precision, recall = compare_bigrams(list_sub_industries, industry_list_golden)
print(f"TP: {tp}, FP: {fp}, FN: {fn}, Precision: {precision}, Recall : {recall}")
# Out:
# 6 6
# TP: 3, FP: 50, FN: 42, Precision: 0.05660377358490566, Recall : 0.06666666666666667

# %% [markdown]
# DSPy optimization

# %%
df_grouped
# Out:
#                                     Theme_Name  \
# 0                          Aerospace & Defence
# 1                             Aging Population
# 2             Autonomous Technology & Robotics
# 3                                Biotechnology
# 4                          Blockchain and Tech
# 5                                 Clean Energy
# 6                              Cloud Computing
# 7                                Cybersecurity
# 8   Data Center REITs & Digital Infrastructure
# 9                           Fintech Innovation
# 10                          Genomic Revolution
# 11                    Genomics & Biotechnology
# 12                                    Hydrogen
# 13                          Internet of Things
# 14                      Lithium & Battery Tech
# 15                            Medical Devices
# 16                    Next Generation Internet
# 17                  Renewable Energy Producers
# 18        Robotics and Artificial Intelligence
# 19                               Semiconductor
# 20                                       Solar
# 21              Space Exploration & Innovation
# 22               Telemedicine & Digital Health
# 23                      Video Games & Esports
# 24                                 Wind Energy
#
#                                          Sub_Industry  \
# 0   Commercial Aircraft Manufacturing, Military Ai...
# 1   Senior Healthcare Services, Assisted Living Fa...
# 2   Autonomous Transportation, Robotics and Automa...
# 3   Pharmaceutical Biotechnology, Agricultural Bio...
# 4   Cryptocurrency Exchanges, Blockchain Developme...
# 5   Solar Power Generation, Wind Power Generation,...
# 6   Infrastructure-as-a-Service (IaaS), Platform-a...
# 7   Network Security, Endpoint Security, Identity ...
# 8   Data Center Real Estate Investment Trusts (REI...
# 9   Transaction Innovations, Blockchain Technology...
# 10  CRISPR, Targeted Therapeutics, Bioinformatics,...
# 11  Gene Editing and CRISPR, Genomic Sequencing, G...
# 12  Hydrogen Production and Generation, Hydrogen S...
# 13  IoT Devices and Sensors, IoT Connectivity Solu...
# 14  Lithium Mining and Extraction, Battery Materia...
# 15  Diagnostic Equipment, Therapeutic Devices, Pat...
# 16  Cloud Computing & Cyber Security, E-Commerce, ...
# 17  Wind Energy Production, Solar Energy Productio...
# 18  Industrial Automation Robotics, AI Software an...
# 19  Semiconductor Fabrication, Semiconductor Desig...
# 20  Solar Photovoltaic (PV) Manufacturing, Solar P...
# 21  Orbital Aerospace, Suborbital Aerospace, Enabl...
# 22  Telemedicine Services, Health Care Analytics, ...
# 23  Game Development and Publishing, Esports Leagu...
# 24  Wind Turbine Manufacturing, Wind Farm Developm...
#
#                                              Keywords
# 0   airliners, passenger jets, cargo planes, aeros...
# 1   geriatric care, home healthcare, telehealth se...
# 2   self-driving cars, autonomous vehicles, electr...
# 3   drug discovery, therapeutic proteins, monoclon...
# 4   cryptocurrency trading, exchange platform, dig...
# 5   photovoltaic systems, solar panels, solar farm...
# 6   virtual servers, cloud storage, network infras...
# 7   intrusion detection systems, firewalls, virtua...
# 8   data center leasing, colocation services, data...
# 9   payment processing, digital wallets, contactle...
# 10  gene editing, genetic engineering, CRISPR-Cas9...
# 11  CRISPR-Cas9, gene therapy, genome editing, tar...
# 12  electrolysis, steam methane reforming, green h...
# 13  smart sensors, wearables, home automation devi...
# 14  lithium mines, brine extraction, hard rock min...
# 15  imaging systems, MRI, CT scans, X-rays, ultras...
# 16  cloud infrastructure, SaaS, PaaS, IaaS, cybers...
# 17  wind farms, turbines, offshore wind, wind powe...
# 18  industrial robots, automation solutions, manuf...
# 19  foundry services, chip manufacturing, wafer pr...
# 20  solar panels, photovoltaic cells, silicon wafe...
# 21  satellite communications, space station, orbit...
# 22  virtual consultations, remote patient monitori...
# 23  game design, game engines, indie games, AAA ti...
# 24  turbine design, blade manufacturing, nacelle a...

# %%
from dspy.teleprompt import BootstrapFewShot
from dspy.teleprompt import LabeledFewShot


def generate_ngrams(s, n):
      s = s.lower()
      tokens = [token for token in s.split(" ") if token != ""]
      ngrams = zip(*[tokens[i:] for i in range(n)])
      return [" ".join(ngram) for ngram in ngrams]

def validate_context_and_answer(example, pred, trace=None):
    print(example.industries.split(","),pred.industries)
    lista=example.industries.split(",")
    listb=pred.industries
    lista = [item.strip() for item in lista]
    lista_bigrams = [generate_ngrams(item, 2) for item in lista]
    score=0
    for b in listb:
      bigrams_b = generate_ngrams(b, 2)
      result = any(set(a) & set(bigrams_b) for a in lista_bigrams)
      score += 5 if result else -1
    industry_EM = True if score >=0 else False
    score=0
    lista=example.keyword.split(",")
    listb=pred.keywords
    lista = [item.strip() for item in lista]
    lista_bigrams = [generate_ngrams(item, 1) for item in lista]
    score=0
    for b in listb:
      bigrams_b = generate_ngrams(b, 1)
      result = any(set(a) & set(bigrams_b) for a in lista_bigrams)
      score += 2 if result else -1
    keyword_EM = True if score >=0 else False
    return industry_EM and keyword_EM
# Set up a basic teleprompter, which will compile our RAG program.
#teleprompter = BootstrapFewShot(metric=validate_context_and_answer)
teleprompter =LabeledFewShot(k=25)

# Compile!
compiled_rag = teleprompter.compile(ThemeToIndustry(), trainset=trainset)

# %%
df_grouped_copy=df_grouped[19:].copy()
theme_list=df_grouped_copy['Theme_Name'].values.tolist()
df_grouped_copy['Sub_Industry'] = df_grouped_copy['Sub_Industry'].str.split(',').apply(lambda x: [i.strip() for i in x])
industry_list_golden = df_grouped_copy['Sub_Industry'].tolist()
df_grouped_copy['Keywords'] =df_grouped_copy['Keywords'].str.split(',').apply(lambda x: [i.strip() for i in x])
Keywords_list_golden = df_grouped_copy['Keywords'].tolist()

# %%
def find_ind_keywords(context,my_question):
  context=context
  pred= compiled_rag(context=context,question=my_question)
  industry_list.append(pred.industries)
  keyword_list.append(pred.keywords)
  return industry_list,keyword_list

# %%
# Ask any question you like to this simple RAG program.
my_question = "Generate seven to fifteen sub-industries that give exposure\
                          to companies associated with the investment theme provided in context"
context='Aerospace & Defence'
pred= compiled_rag(context=context,question=my_question)
print(f"Industries: {pred.industries}")
print(f"Keywords: {pred.keywords}")
# Out:
# Industries: ['Commercial Aircraft Manufacturing', 'Military Aircraft and Systems', 'Space Systems and Exploration', 'Defense Equipment and Armaments', 'Aerospace Components and Systems', 'Unmanned Aerial Vehicles (UAVs)', 'Aerospace Maintenance and Services']
# Keywords: ['fuselage assembly', 'wing design', 'avionics systems', 'composite materials', 'aerodynamics', 'aircraft engines', 'landing gear', 'cabin interiors', 'flight control systems', 'safety regulations', 'aircraft certification', 'fighter jets', 'surveillance drones', 'missile defense systems', 'avionics technology', 'stealth technology', 'electronic warfare', 'tactical aircraft', 'defense electronics', 'military drones', 'combat systems', 'space probes', 'lunar exploration', 'Mars missions', 'satellite technology', 'interplanetary exploration', 'space stations', 'asteroid mining', 'space tourism', 'commercial spaceflight', 'astronomical research', 'fighter jets', 'missile systems', 'tactical aircraft', 'armored vehicles', 'naval ships', 'electronic warfare', 'avionics', 'propulsion systems', 'surveillance drones', 'combat drones', 'avionics', 'propulsion systems', 'flight control systems', 'landing gear', 'aerospace materials', 'composite structures', 'aircraft engines', 'hydraulic systems', 'electrical systems', 'navigation systems', 'drone technology', 'aerial surveillance', 'autonomous flight', 'payload capacity', 'flight endurance', 'remote sensing', 'precision agriculture', 'disaster response', 'military applications', 'commercial drones', 'aircraft maintenance', 'avionics repair', 'engine overhaul', 'component replacement', 'airframe inspection', 'regulatory compliance', 'safety protocols', 'maintenance scheduling', 'predictive maintenance', 'MRO services']

# %%
len(theme_list)
# Out:
# 6

# %%
# Ask any question you like to this simple RAG program.
my_question = "Generate seven to fifteen sub-industries that give exposure\
                          to companies associated with the investment theme provided in context."
industry_list=[]
keyword_list=[]
for context in theme_list:
  industry_list,keyword_list=find_ind_keywords(context,my_question)

# Print the contexts and the answer.
##print(f"Question: {my_question}")
##print(f"Industries: {pred.industries}")
##print(f"Keywords: {pred.keyword}")

# %%
industry_list
# Out:
# [['Semiconductor Manufacturing',
#   'Semiconductor Design',
#   'Semiconductor Equipment',
#   'Semiconductor Materials',
#   'Memory Chips',
#   'Microprocessors',
#   'Analog and Digital Integrated Circuits',
#   'Semiconductor Foundries',
#   'Semiconductor Packaging and Testing',
#   'Application-Specific Integrated Circuits (ASICs)',
#   'System-on-Chip (SoC) Design',
#   'Field-Programmable Gate Arrays (FPGAs)',
#   'Power Management ICs',
#   'Optoelectronics',
#   'Sensors'],
#  ['Solar Panel Manufacturing',
#   'Solar Inverter Manufacturing',
#   'Solar Energy Storage Solutions',
#   'Solar Installation Services',
#   'Solar Project Development',
#   'Solar Financing and Leasing',
#   'Solar Monitoring and Maintenance',
#   'Solar Software and Analytics',
#   'Solar Microgrid Systems',
#   'Solar Thermal Technology',
#   'Solar Energy Consulting Services',
#   'Solar Energy Education and Training',
#   'Solar Energy Research and Development',
#   'Solar Energy Integration with Smart Grids',
#   'Solar Energy Community Programs'],
#  ['Satellite Manufacturing and Launch Services',
#   'Space Tourism',
#   'Space Mining and Resource Utilization',
#   'Space-based Telecommunications',
#   'Earth Observation and Remote Sensing',
#   'Space Debris Management',
#   'Space Habitat and Infrastructure Development',
#   'Space-based Solar Power',
#   'Lunar Exploration and Colonization',
#   'Space Medicine and Healthcare',
#   'Space Robotics and AI',
#   'Space Law and Policy',
#   'Space Education and Outreach',
#   'Space-based Agriculture and Sustainability'],
#  ['Telehealth Platforms',
#   'Remote Patient Monitoring',
#   'Digital Health Apps',
#   'Telemedicine Software Development',
#   'Virtual Consultation Services',
#   'Health Data Analytics',
#   'Wearable Health Technology',
#   'Telepsychiatry Services',
#   'Telemedicine Equipment Providers',
#   'Telemedicine Billing and Coding',
#   'Telemedicine Regulatory Compliance Services',
#   'Telemedicine Training and Education',
#   'Telemedicine Integration Solutions',
#   'Telemedicine Telecommunications Infrastructure'],
#  ['Video Game Development Studios',
#   'Esports Organizations and Teams',
#   'Gaming Hardware Manufacturers',
#   'Gaming Software Publishers',
#   'Streaming Platforms for Gaming and Esports',
#   'Gaming Accessories and Merchandise',
#   'Esports Betting and Gambling Platforms',
#   'Virtual Reality Gaming',
#   'Mobile Gaming Development',
#   'Gaming Events and Tournaments',
#   'Gaming Influencers and Content Creators',
#   'Gaming Analytics and Data Services',
#   'Gaming Communities and Social Platforms',
#   'Gaming Education and Training Programs'],
#  ['Wind Turbine Manufacturing',
#   'Wind Farm Development and Operations',
#   'Wind Energy Storage Solutions',
#   'Offshore Wind Energy',
#   'Wind Energy Software and Analytics',
#   'Wind Energy Consulting Services',
#   'Wind Energy Transmission and Distribution',
#   'Wind Energy Maintenance and Repair',
#   'Wind Energy Financing and Investment',
#   'Wind Energy Research and Development',
#   'Wind Energy Component Manufacturing',
#   'Wind Energy Resource Assessment',
#   'Wind Energy Grid Integration',
#   'Wind Energy Policy and Regulation']]

# %%
keyword_list
# Out:
# [['wafer fabrication',
#   'semiconductor packaging',
#   'testing equipment',
#   'silicon wafers',
#   'integrated circuits',
#   'microprocessors',
#   'memory chips',
#   'semiconductor materials',
#   'semiconductor equipment suppliers',
#   'semiconductor industry trends',
#   'integrated circuits',
#   'semiconductor manufacturing',
#   'chip design',
#   'electronic design automation (EDA)',
#   'semiconductor materials',
#   'silicon wafer fabrication',
#   'transistor technology',
#   'semiconductor testing',
#   'semiconductor packaging',
#   'system-on-chip (SoC) design',
#   'field-programmable gate arrays (FPGAs)',
#   'lithography machines',
#   'wafer inspection systems',
#   'etching equipment',
#   'deposition tools',
#   'metrology systems',
#   'semiconductor testing equipment',
#   'probe stations',
#   'semiconductor packaging equipment',
#   'cleanroom technology',
#   'semiconductor fabrication tools',
#   'silicon wafers',
#   'gallium arsenide substrates',
#   'germanium crystals',
#   'semiconductor materials',
#   'epitaxial growth',
#   'crystal growth techniques',
#   'wafer fabrication',
#   'thin film deposition',
#   'semiconductor packaging',
#   'semiconductor testing',
#   'semiconductor equipment',
#   'cleanroom technology',
#   'semiconductor industry trends',
#   'DRAM',
#   'NAND',
#   'SRAM',
#   'Flash Memory',
#   'Memory Controllers',
#   'Memory Modules',
#   'Memory Testing',
#   'Memory Packaging',
#   'Memory Market Trends',
#   'Memory Chip Manufacturers',
#   'Memory Chip Applications',
#   'silicon wafers',
#   'transistor density',
#   'semiconductor fabrication',
#   'integrated circuits',
#   'CPU architecture',
#   'nanometer technology',
#   "Moore's Law",
#   'chip design',
#   'clock speed',
#   'cache memory',
#   'multi-core processors',
#   'instruction set architecture',
#   'semiconductor devices',
#   'transistor technology',
#   'integrated circuit design',
#   'analog circuits',
#   'digital circuits',
#   'signal processing',
#   'power management',
#   'mixed-signal ICs',
#   'RF circuits',
#   'microcontrollers',
#   'ASIC design',
#   'FPGA technology',
#   'CMOS technology',
#   'semiconductor manufacturing',
#   'wafer fabrication',
#   'lithography',
#   'semiconductor materials',
#   'silicon wafers',
#   'semiconductor packaging',
#   'IC testing',
#   'reliability testing',
#   'failure analysis',
#   'semiconductor manufacturing',
#   'wafer fabrication',
#   'advanced process nodes',
#   'foundry services',
#   'silicon wafers',
#   'semiconductor equipment',
#   'chip design',
#   'integrated circuits',
#   'semiconductor materials',
#   'semiconductor testing',
#   'semiconductor packaging',
#   'semiconductor packaging',
#   'IC testing',
#   'wafer probing',
#   'package assembly',
#   'die bonding',
#   'wire bonding',
#   'flip chip',
#   'ball grid array (BGA)',
#   'chip scale packaging (CSP)',
#   'package reliability testing',
#   'thermal testing',
#   'burn-in testing',
#   'automated test equipment (ATE)',
#   'probe cards',
#   'test sockets',
#   'test handlers',
#   'package inspection',
#   'failure analysis',
#   'package design',
#   'package materials',
#   'lead-free packaging',
#   'advanced packaging technologies',
#   'custom chip design',
#   'specialized hardware',
#   'low-power consumption',
#   'high-performance computing',
#   'application-specific functionality',
#   'semiconductor manufacturing',
#   'integrated system solutions',
#   'ASIC development',
#   'chip optimization',
#   'custom logic design',
#   'integrated circuits',
#   'semiconductor devices',
#   'digital signal processing',
#   'analog circuits',
#   'embedded systems',
#   'ASIC design',
#   'FPGA programming',
#   'hardware description languages',
#   'RTL design',
#   'verification and validation',
#   'power management',
#   'low-power design',
#   'mixed-signal design',
#   'SoC architecture',
#   'system integration',
#   'IP cores',
#   'design automation',
#   'EDA tools',
#   'semiconductor manufacturing',
#   'silicon technology',
#   'wafer fabrication',
#   'packaging and testing',
#   'IC reliability',
#   'thermal management',
#   'electromagnetic interference',
#   'signal integrity',
#   'design for manufacturability',
#   'design for testability.',
#   'programmable logic devices',
#   'reconfigurable hardware',
#   'digital signal processing',
#   'hardware acceleration',
#   'FPGA design tools',
#   'high-performance computing',
#   'embedded systems',
#   'FPGA programming languages',
#   'FPGA architecture',
#   'FPGA applications',
#   'voltage regulators',
#   'power switches',
#   'battery management',
#   'DC-DC converters',
#   'AC-DC converters',
#   'power monitoring',
#   'load switches',
#   'power sequencing',
#   'power factor correction',
#   'energy harvesting',
#   'power distribution',
#   'power efficiency',
#   'LEDs',
#   'photodetectors',
#   'optical sensors',
#   'optoelectronic devices',
#   'semiconductor lasers',
#   'fiber optics',
#   'photonic integrated circuits',
#   'light sensors',
#   'image sensors',
#   'laser diodes',
#   'temperature sensors',
#   'pressure sensors',
#   'motion sensors',
#   'proximity sensors',
#   'humidity sensors',
#   'gas sensors',
#   'optical sensors',
#   'biosensors',
#   'MEMS sensors',
#   'IoT sensors',
#   'wearable sensors'],
#  ['solar cell fabrication',
#   'photovoltaic technology',
#   'thin-film solar panels',
#   'solar panel efficiency',
#   'solar panel recycling',
#   'solar energy storage',
#   'solar panel installation',
#   'solar panel cost reduction',
#   'solar panel innovations',
#   'solar panel market analysis',
#   'grid-tied inverters',
#   'off-grid inverters',
#   'microinverters',
#   'string inverters',
#   'central inverters',
#   'power optimizers',
#   'MPPT technology',
#   'voltage regulation',
#   'efficiency ratings',
#   'monitoring systems',
#   'battery storage',
#   'grid integration',
#   'energy management',
#   'renewable energy storage',
#   'solar power optimization',
#   'off-grid solutions',
#   'energy resilience',
#   'peak shaving',
#   'demand response',
#   'microgrid systems',
#   'lithium-ion batteries',
#   'energy storage systems',
#   'solar panel installation',
#   'renewable energy services',
#   'photovoltaic systems',
#   'solar maintenance',
#   'sustainable energy solutions',
#   'solar repair services',
#   'green technology',
#   'solar energy efficiency',
#   'solar power generation',
#   'eco-friendly installations',
#   'solar panel installation',
#   'photovoltaic systems',
#   'renewable energy projects',
#   'solar energy financing',
#   'solar project management',
#   'solar technology innovation',
#   'solar energy storage',
#   'solar power generation',
#   'solar industry regulations',
#   'solar energy incentives',
#   'solar financing',
#   'solar leases',
#   'power purchase agreements (PPAs)',
#   'solar investment funds',
#   'solar tax credits',
#   'solar incentives',
#   'solar financing options',
#   'solar lease providers',
#   'solar financing companies',
#   'solar project financing',
#   'solar panel monitoring',
#   'performance optimization',
#   'predictive maintenance',
#   'remote diagnostics',
#   'fault detection',
#   'cleaning services',
#   'weather monitoring',
#   'energy yield analysis',
#   'asset management',
#   'solar system maintenance',
#   'solar monitoring software',
#   'predictive maintenance',
#   'performance analytics',
#   'energy optimization',
#   'remote monitoring',
#   'solar asset management',
#   'cloud-based solutions',
#   'real-time data analysis',
#   'solar panel efficiency tracking',
#   'fault detection and diagnostics',
#   'off-grid solar',
#   'distributed energy',
#   'renewable energy systems',
#   'energy storage solutions',
#   'microgrid management',
#   'solar power optimization',
#   'smart grid technology',
#   'community solar projects',
#   'solar energy financing',
#   'solar microgrid integration',
#   'concentrated solar power',
#   'solar collectors',
#   'thermal storage',
#   'parabolic troughs',
#   'solar power towers',
#   'solar desalination',
#   'solar heating systems',
#   'solar thermal plants',
#   'solar thermal energy storage',
#   'solar thermal applications',
#   'solar project development',
#   'renewable energy consulting',
#   'solar feasibility studies',
#   'energy efficiency audits',
#   'solar financing options',
#   'solar panel installation',
#   'solar energy monitoring',
#   'grid integration solutions',
#   'solar energy storage',
#   'solar policy analysis',
#   'solar energy courses',
#   'renewable energy education',
#   'solar panel installation training',
#   'photovoltaic technology classes',
#   'sustainable energy programs',
#   'solar energy certifications',
#   'green energy workshops',
#   'solar energy workforce development',
#   'solar energy training materials',
#   'solar energy career pathways',
#   'photovoltaic technology',
#   'solar panel efficiency',
#   'energy storage solutions',
#   'grid integration',
#   'solar tracking systems',
#   'thin-film solar cells',
#   'solar thermal technology',
#   'concentrated solar power',
#   'solar energy forecasting',
#   'solar-powered desalination',
#   'solar panels',
#   'grid-tied systems',
#   'energy storage solutions',
#   'smart grid technology',
#   'microgrids',
#   'renewable energy integration',
#   'demand response programs',
#   'energy management systems',
#   'distributed energy resources',
#   'grid modernization',
#   'community solar projects',
#   'solar energy education',
#   'solar panel installations',
#   'renewable energy incentives',
#   'energy efficiency programs',
#   'solar financing options',
#   'solar energy workshops',
#   'community outreach',
#   'solar energy advocacy',
#   'local solar initiatives'],
#  ['satellite constellations',
#   'small satellite technology',
#   'satellite propulsion systems',
#   'satellite communication networks',
#   'satellite imaging',
#   'space debris mitigation',
#   'satellite tracking systems',
#   'satellite deployment mechanisms',
#   'reusable launch vehicles',
#   'spaceports',
#   'space travel',
#   'commercial spaceflights',
#   'suborbital tourism',
#   'orbital vacations',
#   'space hotels',
#   'zero-gravity experiences',
#   'astronaut training',
#   'spaceports',
#   'space tourism companies',
#   'lunar tourism',
#   'Mars tourism',
#   'asteroid mining',
#   'lunar regolith extraction',
#   'in-situ resource utilization (ISRU)',
#   'space resource utilization',
#   'extraterrestrial mining',
#   'space resource economics',
#   'space resource governance',
#   'space resource utilization technologies',
#   'space resource prospecting',
#   'space resource utilization policy',
#   'satellite communication',
#   'space-based internet',
#   'satellite networks',
#   'deep space communication',
#   'satellite constellations',
#   'inter-satellite links',
#   'satellite broadband',
#   'space-to-ground communication',
#   'satellite data relay',
#   'space-based telecommunication services',
#   'satellite imaging',
#   'geospatial data',
#   'remote sensing technology',
#   'climate monitoring',
#   'disaster management',
#   'precision agriculture',
#   'urban planning',
#   'natural resource management',
#   'environmental monitoring',
#   'GIS applications',
#   'space debris tracking',
#   'orbital debris removal',
#   'debris mitigation strategies',
#   'space situational awareness',
#   'collision avoidance systems',
#   'debris monitoring technology',
#   'space traffic management',
#   'satellite protection',
#   'debris removal missions',
#   'space debris cleanup technologies',
#   'space habitats',
#   'extraterrestrial construction',
#   'life support systems',
#   'radiation shielding',
#   'space agriculture',
#   '3D printing in space',
#   'in-situ resource utilization',
#   'lunar bases',
#   'Mars colonization',
#   'space tourism',
#   'space stations',
#   'space mining',
#   'asteroid mining',
#   'space debris mitigation',
#   'space elevator',
#   'orbital manufacturing',
#   'spaceports',
#   'space logistics',
#   'space habitats design',
#   'space-based solar power',
#   'orbital solar arrays',
#   'wireless power transmission',
#   'solar panels in space',
#   'energy beaming',
#   'space-based energy solutions',
#   'sustainable energy innovation',
#   'space infrastructure',
#   'satellite power generation',
#   'extraterrestrial solar energy',
#   'lunar habitats',
#   'regolith utilization',
#   'lunar rovers',
#   'ISRU (In-Situ Resource Utilization)',
#   'lunar mining',
#   'water extraction',
#   'lunar agriculture',
#   '3D printing on the Moon',
#   'lunar tourism',
#   'lunar research stations',
#   'space medicine',
#   'astronaut health',
#   'microgravity effects',
#   'radiation exposure',
#   'telemedicine in space',
#   'space pharmacology',
#   'space radiation protection',
#   'space psychology',
#   'space food technology',
#   'exercise physiology in space',
#   'space healthcare technology',
#   'autonomous space robots',
#   'AI-powered spacecraft',
#   'robotic arms for space missions',
#   'space exploration drones',
#   'autonomous rovers',
#   'AI-assisted space navigation',
#   'robotic assembly in space',
#   'space debris removal robots',
#   'AI for space habitat design',
#   'autonomous space mining robots',
#   'space treaties',
#   'space regulations',
#   'space governance',
#   'international space law',
#   'space policy',
#   'space ethics',
#   'space jurisdiction',
#   'space liability',
#   'space debris mitigation',
#   'space resource utilization',
#   'space exploration laws',
#   'astronomy education',
#   'STEM outreach',
#   'space camps',
#   'planetarium shows',
#   'space science curriculum',
#   'astronaut training programs',
#   'space-themed events',
#   'educational resources',
#   'space exploration workshops',
#   'public lectures',
#   'interactive exhibits',
#   'space farming',
#   'hydroponics in space',
#   'closed-loop life support systems',
#   'regenerative agriculture',
#   'space habitat design',
#   'plant growth experiments',
#   'space agriculture research',
#   'sustainable food production',
#   'resource recycling',
#   'space-based ecosystem management'],
#  ['telemedicine',
#   'virtual consultations',
#   'remote monitoring',
#   'telehealth apps',
#   'telepsychiatry',
#   'telecardiology',
#   'teletriage',
#   'e-prescriptions',
#   'telehealth platforms',
#   'digital health records',
#   'telehealth platforms',
#   'wearable health devices',
#   'remote monitoring solutions',
#   'virtual consultations',
#   'digital health apps',
#   'patient engagement tools',
#   'telemedicine technology',
#   'chronic disease management',
#   'real-time health data analysis',
#   'telehealth reimbursement',
#   'telemedicine regulations',
#   'telehealth platforms',
#   'remote patient monitoring',
#   'virtual consultations',
#   'mHealth apps',
#   'health tracking apps',
#   'telepsychiatry services',
#   'telemedicine software',
#   'patient engagement tools',
#   'digital therapeutics',
#   'wearable health technology',
#   'telehealth platforms',
#   'virtual consultations',
#   'remote monitoring',
#   'telemedicine apps',
#   'digital health records',
#   'telepsychiatry',
#   'telecardiology',
#   'teleoncology',
#   'teletherapy',
#   'telemedicine regulations',
#   'telehealth platforms',
#   'virtual doctor visits',
#   'remote patient monitoring',
#   'digital health apps',
#   'telemedicine technology',
#   'teleconsultation services',
#   'telehealth solutions',
#   'online healthcare services',
#   'telemedicine platforms',
#   'virtual healthcare consultations',
#   'predictive modeling',
#   'data visualization',
#   'patient monitoring',
#   'healthcare analytics',
#   'population health management',
#   'real-time data analysis',
#   'electronic health records (EHR)',
#   'telehealth platforms',
#   'remote patient monitoring',
#   'health informatics',
#   'wearable health monitors',
#   'remote patient monitoring',
#   'health tracking devices',
#   'telehealth platforms',
#   'medical wearables',
#   'health data analytics',
#   'personalized health technology',
#   'continuous health monitoring',
#   'smart health devices',
#   'connected health solutions',
#   'telepsychiatry',
#   'online therapy',
#   'virtual counseling',
#   'mental health apps',
#   'remote psychiatric care',
#   'digital mental health platforms',
#   'telemedicine for mental health',
#   'telepsychology',
#   'e-mental health',
#   'telebehavioral health',
#   'telemedicine platforms',
#   'virtual care solutions',
#   'remote patient monitoring',
#   'telehealth technology',
#   'digital health devices',
#   'telemedicine software',
#   'telehealth services',
#   'telemedicine equipment',
#   'telemedicine devices',
#   'telehealth platforms',
#   'telehealth CPT codes',
#   'telemedicine modifiers',
#   'telehealth reimbursement',
#   'telemedicine compliance',
#   'remote patient monitoring billing',
#   'virtual care coding',
#   'telehealth documentation',
#   'telemedicine audits',
#   'telehealth revenue cycle management',
#   'telemedicine regulations',
#   'HIPAA compliance',
#   'telehealth laws',
#   'healthcare data security',
#   'telemedicine licensing',
#   'telemedicine reimbursement',
#   'telehealth privacy',
#   'virtual care compliance',
#   'remote patient monitoring regulations',
#   'telemedicine certification',
#   'online telehealth courses',
#   'virtual healthcare training',
#   'remote medical education',
#   'telemedicine workshops',
#   'digital health seminars',
#   'telehealth skills development',
#   'e-learning for telemedicine',
#   'telemedicine best practices',
#   'telehealth technology training',
#   'telehealth platforms',
#   'remote patient monitoring',
#   'virtual consultations',
#   'digital health records',
#   'telemedicine software',
#   'telehealth devices',
#   'telemedicine regulations',
#   'telehealth reimbursement',
#   'telemedicine technology',
#   'telehealth services',
#   'remote patient monitoring',
#   'virtual consultations',
#   'digital health platforms',
#   'telemedicine apps',
#   'telepharmacy services',
#   'telepsychiatry',
#   'telecardiology',
#   'teleoncology',
#   'tele-ICU',
#   'e-prescriptions',
#   'telemonitoring',
#   'wearable health technology',
#   'telehealth reimbursement',
#   'telemedicine regulations',
#   'telehealth adoption',
#   'telehealth integration',
#   'telehealth interoperability',
#   'telehealth security'],
#  ['game development',
#   'game design',
#   'game engines',
#   'virtual reality',
#   'augmented reality',
#   'mobile gaming',
#   'PC gaming',
#   'console gaming',
#   'indie games',
#   'esports',
#   'live streaming',
#   'game monetization',
#   'in-game purchases',
#   'microtransactions',
#   'game marketing',
#   'player engagement',
#   'community management',
#   'game testing',
#   'game localization',
#   'professional gamers',
#   'Esports tournaments',
#   'gaming leagues',
#   'team sponsorships',
#   'streaming platforms',
#   'fan engagement',
#   'competitive gaming',
#   'Esports organizations',
#   'team merchandising',
#   'player contracts',
#   'Esports events',
#   'prize pools',
#   'gaming influencers',
#   'Esports fans',
#   'team rivalries',
#   'online gaming communities',
#   'Esports broadcasting',
#   'team management',
#   'talent scouting',
#   'gaming peripherals',
#   'gaming laptops',
#   'gaming desktops',
#   'gaming monitors',
#   'gaming accessories',
#   'RGB lighting',
#   'mechanical keyboards',
#   'gaming mice',
#   'gaming headsets',
#   'gaming chairs',
#   'ergonomic design',
#   'high refresh rate displays',
#   'customizable hardware',
#   'esports equipment',
#   'video game development',
#   'game publishing',
#   'game distribution',
#   'game monetization',
#   'game engines',
#   'esports tournaments',
#   'professional gaming',
#   'streaming platforms',
#   'content creation',
#   'gaming peripherals',
#   'virtual reality gaming',
#   'mobile gaming',
#   'online multiplayer games',
#   'gaming communities',
#   'competitive gaming',
#   'gaming influencers',
#   'esports sponsorships',
#   'gaming events',
#   'live streaming',
#   'gaming content',
#   'esports tournaments',
#   'Twitch',
#   'YouTube Gaming',
#   'Mixer',
#   'streaming community',
#   'interactive broadcasts',
#   'viewer engagement',
#   'content creators',
#   'monetization opportunities',
#   'gaming peripherals',
#   'custom controllers',
#   'gaming chairs',
#   'RGB lighting',
#   'esports jerseys',
#   'gaming headsets',
#   'mouse pads',
#   'collectible figurines',
#   'gaming apparel',
#   'limited edition merchandise',
#   'live betting',
#   'in-play wagering',
#   'esports tournaments',
#   'virtual sports betting',
#   'skin gambling',
#   'loot boxes',
#   'esports odds',
#   'esportsbook',
#   'fantasy esports',
#   'esports betting markets',
#   'virtual reality headsets',
#   'VR gaming platforms',
#   'immersive gameplay',
#   'interactive environments',
#   'motion tracking technology',
#   'haptic feedback',
#   '3D audio',
#   'virtual reality arcades',
#   'VR content creation',
#   'augmented reality integration',
#   'mobile game genres',
#   'in-app purchases',
#   'player retention',
#   'game development tools',
#   'augmented reality games',
#   'multiplayer mobile games',
#   'hyper-casual games',
#   'mobile esports',
#   'mobile game monetization',
#   'mobile game marketing strategies',
#   'esports tournaments',
#   'gaming events',
#   'competitive gaming',
#   'live streaming',
#   'prize pools',
#   'sponsorships',
#   'professional gamers',
#   'audience engagement',
#   'online multiplayer',
#   'LAN parties',
#   'gaming conventions',
#   'gaming streamers',
#   'esports influencers',
#   'content creation',
#   'live streaming',
#   'audience engagement',
#   'sponsorships',
#   'brand collaborations',
#   'gaming tournaments',
#   'social media presence',
#   'influencer marketing',
#   'player analytics',
#   'engagement tracking',
#   'in-game data analysis',
#   'esports performance metrics',
#   'market research',
#   'player segmentation',
#   'competitive intelligence',
#   'game telemetry',
#   'user retention analysis',
#   'monetization strategies',
#   'gaming forums',
#   'esports tournaments',
#   'live streaming',
#   'virtual events',
#   'gaming influencers',
#   'online gaming communities',
#   'social gaming platforms',
#   'multiplayer gaming',
#   'competitive gaming',
#   'gaming content creators',
#   'game design courses',
#   'esports coaching programs',
#   'gaming industry certifications',
#   'virtual reality training',
#   'game development bootcamps',
#   'streaming workshops',
#   'esports marketing courses',
#   'game art and animation classes',
#   'competitive gaming academies',
#   'game programming degrees'],
#  ['wind turbine design',
#   'blade manufacturing',
#   'tower construction',
#   'offshore wind farms',
#   'onshore wind projects',
#   'wind energy efficiency',
#   'turbine maintenance',
#   'renewable energy sources',
#   'wind power generation',
#   'wind turbine technology',
#   'wind turbines',
#   'renewable energy',
#   'sustainable power generation',
#   'wind farm management',
#   'turbine maintenance',
#   'wind energy efficiency',
#   'grid integration',
#   'wind power capacity',
#   'offshore wind projects',
#   'wind energy financing',
#   'grid-scale energy storage',
#   'battery technology',
#   'renewable energy storage',
#   'wind energy technology',
#   'energy management systems',
#   'lithium-ion batteries',
#   'pumped hydro storage',
#   'energy storage solutions',
#   'thermal storage',
#   'battery safety innovations',
#   'offshore wind farms',
#   'wind turbine technology',
#   'deep-water installations',
#   'floating wind turbines',
#   'subsea power cables',
#   'offshore wind energy production',
#   'marine wildlife protection',
#   'seabed surveys',
#   'offshore wind market growth',
#   'renewable energy transition.',
#   'wind farm optimization',
#   'predictive maintenance',
#   'performance analytics',
#   'turbine monitoring',
#   'energy forecasting',
#   'asset management',
#   'condition monitoring',
#   'data-driven insights',
#   'remote monitoring',
#   'predictive analytics',
#   'wind resource assessment',
#   'project feasibility',
#   'environmental impact assessment',
#   'permitting process',
#   'financial modeling',
#   'project financing',
#   'construction management',
#   'operations and maintenance',
#   'grid integration',
#   'energy storage solutions',
#   'grid integration',
#   'smart grid technology',
#   'energy storage solutions',
#   'transmission infrastructure',
#   'grid reliability',
#   'power quality',
#   'grid modernization',
#   'renewable energy integration',
#   'grid stability',
#   'energy management systems',
#   'wind turbine maintenance',
#   'blade inspection',
#   'gearbox repair',
#   'predictive maintenance',
#   'condition monitoring',
#   'rotor balancing',
#   'tower maintenance',
#   'offshore wind farms',
#   'drone inspections',
#   'maintenance scheduling',
#   'project financing',
#   'renewable energy investments',
#   'wind farm development',
#   'tax equity financing',
#   'power purchase agreements',
#   'energy asset management',
#   'green bonds',
#   'sustainable finance',
#   'wind energy funds',
#   'wind turbine leasing',
#   'wind turbine design',
#   'blade technology',
#   'wind farm optimization',
#   'offshore wind energy',
#   'wind resource assessment',
#   'grid integration',
#   'energy storage solutions',
#   'wind energy policy',
#   'community engagement',
#   'environmental impact assessment',
#   'wind turbine blades',
#   'rotor hubs',
#   'nacelles',
#   'gearboxes',
#   'generators',
#   'pitch systems',
#   'yaw systems',
#   'tower structures',
#   'offshore wind technology',
#   'wind farm maintenance',
#   'wind resource assessment',
#   'wind data analysis',
#   'wind mapping',
#   'wind energy potential',
#   'wind turbine placement',
#   'micrositing',
#   'wind farm optimization',
#   'meteorological towers',
#   'remote sensing technology',
#   'lidar measurements',
#   'wind atlas',
#   'wind energy forecasting',
#   'wind energy software',
#   'wind farm optimization',
#   'grid connection',
#   'energy storage systems',
#   'grid stability',
#   'renewable energy integration',
#   'transmission infrastructure',
#   'smart grid technology',
#   'power electronics',
#   'energy management systems',
#   'grid balancing',
#   'wind forecasting',
#   'wind energy subsidies',
#   'renewable energy targets',
#   'feed-in tariffs',
#   'net metering',
#   'power purchase agreements',
#   'renewable portfolio standards',
#   'offshore wind regulations',
#   'environmental impact assessments',
#   'grid connection requirements',
#   'community engagement',
#   'wind energy permitting',
#   'wind turbine zoning',
#   'wildlife protection measures',
#   'noise regulations',
#   'decommissioning plans']]

# %%
print(len(industry_list), len(industry_list_golden))
# Out:
# 6 6

# %%
def create_bigrams(lst):
    bigrams = set()
    for sublist in lst:
        for string in sublist:
            words = string.split()
            words=[word.lower().strip() for word in words]
            for i in range(len(words)-1):
                bigrams.add((words[i], words[i+1]))

    return [bigram for bigram in bigrams if 'and' not in bigram and 'for' not in bigram and  'or' not in bigram and 'in' not in bigram]



def compare_bigrams(industry_list, industry_list_golden):
    bigrams_industry = create_bigrams(industry_list)
    bigrams_golden = create_bigrams(industry_list_golden)

    tp = sum(1 for bigram in bigrams_industry if bigram in bigrams_golden)
    fp = sum(1 for bigram in bigrams_industry if bigram not in bigrams_golden)
    fn = sum(1 for bigram in bigrams_golden if bigram not in bigrams_industry)

    return tp, fp, fn ,tp/(tp+fp) , tp/(tp+fn)

tp, fp, fn ,precision ,recall  = compare_bigrams(industry_list, industry_list_golden)
print(f"TP: {tp}, FP: {fp}, FN: {fn}, Precision: {precision}, Recall : {recall}")
# Out:
# TP: 19, FP: 114, FN: 39, Precision: 0.14285714285714285, Recall : 0.3275862068965517

# %%
def compare_bigrams(keywords_list, keywords_list_golden):
    bigrams_industry = create_bigrams(keywords_list)
    bigrams_golden = create_bigrams(keywords_list_golden)

    tp = sum(1 for bigram in bigrams_industry if bigram in bigrams_golden)
    fp = sum(1 for bigram in bigrams_industry if bigram not in bigrams_golden)
    fn = sum(1 for bigram in bigrams_golden if bigram not in bigrams_industry)


    return tp, fp, fn

tp, fp, fn = compare_bigrams(keyword_list, Keywords_list_golden)
print(f"TP: {tp}, FP: {fp}, FN: {fn}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-4b0da8c0765a> in <cell line: 12>()
#      10     return tp, fp, fn
#      11
# ---> 12 tp, fp, fn = compare_bigrams(keyword_list, Keywords_list_golden)
#      13 print(f"TP: {tp}, FP: {fp}, FN: {fn}")
#
# NameError: name 'keyword_list' is not defined

# %% [markdown]
# DSPy LLM using Turbo3.5 for retrieving the Industry and key words

# %%
lm2 = dspy.OpenAI(model='gpt-3.5-turbo', api_key='')
colbert_server = 'http://index.contextual.ai:8893/api/search'
rm2 = dspy.ColBERTv2(url=colbert_server)
dspy.settings.configure(lm=lm2, rm=rm2)

# %%
import dspy

class GenerateThemeIndustry(dspy.Signature):
    """
     Your task is to Generate  seven to fifteen sub-industries that give
     exposure to companies associated with the investment theme provided in context.
     Please use the context to  generate the  sub-industries"""
    context = dspy.InputField()
    question=dspy.InputField()
    industries = dspy.OutputField(desc="A comma separated list of seven to fifteen Sub-industries associated with context")

class GenerateThemekeywords(dspy.Signature):
    """
     Your task is to Generate five to ten  keyword associated with the industry given the investment theme in the context.
    The number of keywords must not exceed 10"""
    context = dspy.InputField()
    industry=dspy.InputField()
    keyword = dspy.OutputField(desc="five to ten semantic keywords associated with the each sub-industry")

def convert_to_list(s):
    # Check if the string contains numbered list items
    if '\n' in s and s[1] == '.':
        # Split the string into lines and remove the first three characters from each line
        return [item[3:] for item in s.split('\n') if item[3:] != '']
    else:
        # Split the string by comma
        return [item.strip() for item in s.split(',')]

class ThemeToIndustry(dspy.Module):
    def __init__(self):
        super().__init__()
        # Define the predictor to implement the GenerateThemeIndustry signature.
        self.generate_industry = dspy.ChainOfThought(GenerateThemeIndustry)
        self.generate_keywords = dspy.ChainOfThought(GenerateThemekeywords)

    def forward(self, context, question):
        # Generate sub-industries and their associated bag of key-words
        sub_industries = self.generate_industry(context=context,question=question)
        subindustries=convert_to_list(sub_industries.industries)
        keywords_list=[]
        for sub_industry in subindustries:
            new_keywords = self.generate_keywords(context=context,industry=sub_industry)
            keywordslist=convert_to_list(new_keywords.keyword)
            keywords_list.extend(keywordslist)
        return dspy.Prediction(industries=subindustries,keywords=keywords_list)

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/2Stanford/2nlp/Hybrid_Mkt_GPT_4_Theme_Industry_Keywords.csv')
trainset = []
df_grouped = df.groupby('Theme_Name').agg({
    'Sub_Industry': ', '.join,
    'Keywords': ', '.join
}).reset_index()
for _, row in df_grouped.iterrows():
    context = f"Given the context as {row['Theme_Name']}"
    question = "Generate seven to fifteen sub-industries that give exposure to companies associated with the investment theme provided in context"

    industries = row['Sub_Industry']
    keyword = row['Keywords']
    example = dspy.Example(context=context, question=question, industries=industries, keyword=keyword).with_inputs('context','question')
    trainset.append(example)

# %%
my_question = "Generate seven to fifteen sub-industries that give exposure\
                          to companies associated with the investment theme provided in context"
context='Aerospace & Defence'
theme_pred = ThemeToIndustry()(context=context,question=my_question)
print(theme_pred.industries)
print(theme_pred.keywords)
# Out:
# ['Commercial Aerospace', 'Defense Technology', 'Aerospace Components', 'Military Aircraft', 'Space Exploration', 'Defense Electronics', 'Aerospace Engineering', 'Defense Contractors', 'Satellite Communications', ' Air Traffic Control Systems', ' Defense Training and Simulation', ' Unmanned Aerial Vehicles (UAVs)', ' Missile Defense Systems', ' Aerospace Maintenance, Repair, and Overhaul (MRO)', ' Defense Cybersecurity']
# ['Aircraft manufacturing', 'Airline industry', 'Aerospace engineering', 'Aviation technology', 'Commercial aircraft', 'Aerospace supply chain', 'Passenger air travel', 'Aerospace innovation', 'Aircraft maintenance', ' Aerospace market analysis', 'Advanced weaponry', 'Cybersecurity', 'Surveillance technology', 'Military communication systems', 'Drone technology', 'Radar systems', 'Biometric security', 'Satellite technology', 'Electronic warfare', ' Autonomous vehicles', 'Aircraft parts', 'Aerospace fasteners', 'Avionics components', 'Engine components', 'Structural components', 'Aerospace materials', 'Landing gear components', 'Cabin interiors', 'Wing components', ' Propulsion systems', 'Fighter jets', 'Bombers', 'Military drones', 'Stealth technology', 'Air-to-air missiles', 'Electronic warfare', 'Radar systems', 'Avionics', 'Military aviation', ' Defense contracts', 'Satellite technology', 'Rocket propulsion', 'Lunar exploration', 'Mars mission', 'Space tourism', 'International Space Station', 'Space debris management', 'Astronaut training', 'Space telescopes', ' Planetary rovers', 'Radar systems', 'Electronic warfare', 'Communication systems', 'Surveillance technology', 'Missile guidance systems', 'Cybersecurity solutions', 'Signal processing', 'Avionics', 'Unmanned aerial vehicles (UAVs)', ' Electronic countermeasures', 'Aircraft design', 'Aerospace materials', 'Avionics systems', 'Propulsion technology', 'Aerodynamics', 'Structural engineering', 'Space exploration', 'Satellite technology', 'Defense contracts', ' Aerospace innovation', 'Military equipment', 'Government contracts', 'Aerospace technology', 'Defense systems', 'National security', 'Defense spending', 'Cybersecurity solutions', 'Missile defense', 'Intelligence services', ' Military logistics', 'Satellite technology', 'Communication satellites', 'Satellite networks', 'Satellite broadband', 'Satellite imagery', 'Satellite tracking', 'Satellite data', 'Satellite launches', 'Satellite ground stations', ' Satellite communication systems', 'Radar systems', 'Communication systems', 'Surveillance technology', 'Navigation systems', 'Flight data processing', 'Airspace management', 'Traffic flow optimization', 'Safety regulations', 'Airport operations', ' Remote monitoring', 'Military simulation', 'Virtual training', 'Tactical scenarios', 'Simulation software', 'Combat training', 'Virtual reality training', 'Simulation technology', 'Defense readiness', 'Training exercises', ' Mission rehearsal', 'Drone technology', 'Military drones', 'Commercial UAVs', 'Autonomous flight', 'UAV regulations', 'Surveillance drones', 'Drone delivery', 'Precision agriculture', 'UAV market growth', ' Drone software', 'Interceptor missiles', 'Ballistic missile defense', 'Anti-satellite weapons', 'Radar systems', 'Missile defense technology', 'National security', 'Strategic defense', 'Missile defense budget', 'Missile defense shield', ' Missile defense capabilities', 'Aircraft maintenance', 'Component repair', 'Overhaul services', 'MRO facilities', 'Aviation maintenance', 'Engine maintenance', 'Aircraft inspections', 'Repair technicians', 'Maintenance procedures', ' Aerospace industry regulations', 'Cyber threats', 'Network security', 'Data protection', 'Vulnerability assessment', 'Incident response', 'Encryption technology', 'Risk management', 'Compliance regulations', 'Threat intelligence', ' Security operations']

# %%
df_grouped_copy=df_grouped.copy()
theme_list=df_grouped['Theme_Name'].values.tolist()
df_grouped['Sub_Industry'] = df_grouped['Sub_Industry'].str.split(',').apply(lambda x: [i.strip() for i in x])
industry_list_golden = df_grouped['Sub_Industry'].tolist()
df_grouped['Keywords'] = df_grouped['Keywords'].str.split(',').apply(lambda x: [i.strip() for i in x])
Keywords_list_golden = df_grouped['Keywords'].tolist()

# %%
Keywords_list_golden
# Out:
# [['airliners',
#   'passenger jets',
#   'cargo planes',
#   'aerospace engineering',
#   'aviation technology',
#   'assembly lines',
#   'fighter jets',
#   'military drones',
#   'surveillance aircraft',
#   'missile systems',
#   'defense electronics',
#   'tactical aircraft',
#   'satellites',
#   'space probes',
#   'launch vehicles',
#   'space stations',
#   'lunar exploration',
#   'Mars missions',
#   'armored vehicles',
#   'naval ships',
#   'submarines',
#   'artillery systems',
#   'smart munitions',
#   'electronic warfare',
#   'avionics',
#   'propulsion systems',
#   'flight control systems',
#   'landing gear',
#   'aerospace materials',
#   'composite structures',
#   'drones',
#   'UAV systems',
#   'autonomous flight',
#   'surveillance drones',
#   'combat drones',
#   'drone navigation',
#   'MRO (maintenance',
#   'repair',
#   'and overhaul)',
#   'retrofitting',
#   'upgrades',
#   'flight training',
#   'simulation systems',
#   'logistic support'],
#  ['geriatric care',
#   'home healthcare',
#   'telehealth services',
#   'chronic disease management',
#   'medical alert systems',
#   'gerontology',
#   'senior living communities',
#   'retirement homes',
#   'assisted living services',
#   'memory care',
#   'long-term care facilities',
#   'community wellness',
#   'geriatric medicines',
#   'age-related therapeutics',
#   'dementia treatment',
#   'osteoporosis drugs',
#   'longevity research',
#   'clinical trials',
#   'mobility aids',
#   'hearing aids',
#   'medical wearables',
#   'health monitoring devices',
#   'orthopedic implants',
#   'assistive technology',
#   'dietary supplements',
#   'senior nutrition',
#   'functional foods',
#   'age-specific vitamins',
#   'nutritional therapy',
#   'health supplements',
#   'retirement planning',
#   'estate planning',
#   'wealth management for seniors',
#   'annuities',
#   'financial advising',
#   'elder financial protection',
#   'adaptive clothing',
#   'age-friendly design',
#   'senior transportation services',
#   'ergonomic products',
#   'home retrofitting services'],
#  ['self-driving cars',
#   'autonomous vehicles',
#   'electric vehicles',
#   'drone delivery',
#   'smart transportation systems',
#   'vehicle telematics',
#   'industrial robots',
#   'service robots',
#   'robotic process automation',
#   'artificial intelligence in robotics',
#   'collaborative robots',
#   'automation software',
#   'additive manufacturing',
#   'rapid prototyping',
#   '3D printers',
#   'printable materials',
#   'digital fabrication',
#   'custom manufacturing',
#   '3D modeling software',
#   'battery technology',
#   'lithium-ion batteries',
#   'renewable energy storage',
#   'grid storage solutions',
#   'energy management systems',
#   'supercapacitors',
#   'spacecraft',
#   'space missions',
#   'satellite technology',
#   'interplanetary exploration',
#   'space mining',
#   'astronomical research',
#   'commercial spaceflight'],
#  ['drug discovery',
#   'therapeutic proteins',
#   'monoclonal antibodies',
#   'vaccine development',
#   'clinical trials',
#   'pharmacogenomics',
#   'genetically modified organisms (GMOs)',
#   'crop yield improvement',
#   'biopesticides',
#   'plant biotech',
#   'agricultural genomics',
#   'biofuels',
#   'biocatalysis',
#   'fermentation technology',
#   'biodegradable materials',
#   'bio-based chemicals',
#   'industrial enzymes',
#   'bioremediation',
#   'wastewater treatment',
#   'biofiltration',
#   'environmental monitoring',
#   'green technology',
#   'waste management',
#   'diagnostic tests',
#   'medical imaging',
#   'regenerative medicine',
#   'wearable health technology',
#   'lab-on-a-chip',
#   'precision medicine',
#   'genome sequencing',
#   'gene editing (CRISPR)',
#   'proteomics analysis',
#   'bioinformatics',
#   'molecular diagnostics',
#   'personalized genomics',
#   'computational biology',
#   'genetic data analysis',
#   'systems biology',
#   'molecular modeling',
#   'next-generation sequencing data',
#   'AI in biotech'],
#  ['cryptocurrency trading',
#   'exchange platform',
#   'digital wallets',
#   'liquidity services',
#   'order matching',
#   'security protocols',
#   'transaction processing',
#   'smart contracts',
#   'blockchain protocols',
#   'distributed applications (dApps)',
#   'development frameworks',
#   'API services',
#   'consensus mechanisms',
#   'decentralized exchanges (DEX)',
#   'lending protocols',
#   'staking',
#   'governance tokens',
#   'decentralized autonomous organizations (DAOs)',
#   'DeFi applications',
#   'tokenization',
#   'digital asset custody',
#   'blockchain-based asset tracking',
#   'investment tokens',
#   'portfolio management on blockchain',
#   'contract development',
#   'audit and compliance',
#   'on-chain verification',
#   'decentralized oracles',
#   'Ethereum',
#   'chainlink',
#   'product traceability',
#   'anti-counterfeit measures',
#   'logistics optimization',
#   'real-time data',
#   'supply chain finance',
#   'blockchain-enabled provenance',
#   'mining hardware',
#   'hash power',
#   'mining pools',
#   'energy consumption',
#   'mining algorithms',
#   'Proof of Work',
#   'Proof of Stake'],
#  ['photovoltaic systems',
#   'solar panels',
#   'solar farms',
#   'concentrated solar power',
#   'residential solar solutions',
#   'wind turbines',
#   'offshore wind farms',
#   'wind energy technology',
#   'wind resource assessment',
#   'wind power plants',
#   'hydro plants',
#   'dam technology',
#   'run-of-river systems',
#   'pumped-storage hydroelectricity',
#   'micro-hydro systems',
#   'biofuels',
#   'biopower',
#   'anaerobic digestion',
#   'biomass to electricity',
#   'sustainable biomass',
#   'geothermal power stations',
#   'heat pumps',
#   'geothermal drilling',
#   'enhanced geothermal systems',
#   'tidal barrages',
#   'wave energy converters',
#   'ocean energy systems',
#   'marine current power',
#   'battery storage',
#   'thermal storage',
#   'pumped hydro storage',
#   'flywheel energy storage',
#   'grid-scale energy storage'],
#  ['virtual servers',
#   'cloud storage',
#   'network infrastructure',
#   'scalable computing resources',
#   'disaster recovery',
#   'on-demand computing',
#   'development tools',
#   'application hosting',
#   'database management',
#   'business analytics',
#   'middleware',
#   'application development platforms',
#   'cloud applications',
#   'subscription software',
#   'CRM',
#   'ERP',
#   'collaboration tools',
#   'office suites',
#   'customer service software',
#   'data center leasing',
#   'colocation services',
#   'data center real estate',
#   'interconnection services',
#   'cloud data center facilities',
#   'identity management',
#   'cloud access security',
#   'data privacy',
#   'regulatory compliance',
#   'security assessment',
#   'encryption services',
#   'distributed computing',
#   'edge devices',
#   'real-time data processing',
#   'latency reduction',
#   'edge data centers',
#   'IoT edge solutions'],
#  ['intrusion detection systems',
#   'firewalls',
#   'virtual private networks (VPNs)',
#   'network monitoring',
#   'security operations centers (SOCs)',
#   'antivirus software',
#   'anti-malware',
#   'endpoint protection platforms (EPP)',
#   'mobile device security',
#   'endpoint detection and response (EDR)',
#   'single sign-on (SSO)',
#   'multi-factor authentication (MFA)',
#   'identity verification',
#   'access controls',
#   'user behavior analytics',
#   'cloud access security brokers (CASBs)',
#   'secure web gateways',
#   'cloud workload protection',
#   'encryption in transit and at rest',
#   'data loss prevention (DLP)',
#   'encryption algorithms',
#   'tokenization',
#   'database security',
#   'secure data storage solutions',
#   'security information and event management (SIEM)',
#   'threat hunting',
#   'incident response',
#   'cyber threat intelligence platforms',
#   'application firewalls',
#   'secure coding practices',
#   'application security testing',
#   'software composition analysis'],
#  ['data center leasing',
#   'colocation services',
#   'data center operations',
#   'real estate portfolio',
#   'interconnection ecosystems',
#   'fiber optic networks',
#   'bandwidth management',
#   'telecommunications infrastructure',
#   'network as a service (NaaS)',
#   'backbone networks',
#   'cloud hosting services',
#   'managed services',
#   'Infrastructure-as-a-Service (IaaS)',
#   'data storage solutions',
#   'on-demand computing resources',
#   'edge computing facilities',
#   'latency optimization',
#   'content delivery networks',
#   'edge server locations',
#   'distributed computing architecture',
#   'network support services',
#   'infrastructure management',
#   'IT support',
#   'virtual infrastructure',
#   'systems integration',
#   'broadband services',
#   'wireless infrastructure',
#   'internet exchange points',
#   'connectivity products',
#   'high-speed internet access',
#   'data center architecture',
#   'modular data centers',
#   'cooling solutions',
#   'power efficiency',
#   'green data centers'],
#  ['payment processing',
#   'digital wallets',
#   'contactless payments',
#   'mobile payments',
#   'real-time transactions',
#   'cross-border payments',
#   'P2P payments',
#   'distributed ledger technology',
#   'blockchain platforms',
#   'smart contracts',
#   'tokenization',
#   'decentralized applications',
#   'crypto assets',
#   'blockchain security',
#   'risk management',
#   'regulatory technology',
#   'compliance automation',
#   'fraud detection',
#   'credit risk',
#   'cyber risk',
#   'insurtech',
#   'crowdfunding',
#   'peer-to-peer lending',
#   'microfinancing',
#   'investment platforms',
#   'robo-advisors',
#   'financial automation',
#   'seamless transactions',
#   'personal finance management',
#   'customer engagement',
#   'digital banking',
#   'mobile banking',
#   'financial planning tools',
#   'chatbots',
#   'AI customer service',
#   'financial marketplaces',
#   'comparison platforms',
#   'API banking',
#   'Banking-as-a-Service',
#   'platform banking',
#   'disintermediation',
#   'open banking'],
#  ['gene editing',
#   'genetic engineering',
#   'CRISPR-Cas9',
#   'genome modification',
#   'gene therapy',
#   'biotechnology',
#   'molecular targeting',
#   'precision medicine',
#   'drug development',
#   'targeted therapy',
#   'biopharmaceuticals',
#   'molecular medicine',
#   'personalized treatment',
#   'pharmacogenomics',
#   'computational biology',
#   'genomics data',
#   'biological database',
#   'sequence analysis',
#   'proteomics',
#   'systems biology',
#   'bioinformatics tools',
#   'diagnostic assays',
#   'molecular testing',
#   'biomarkers',
#   'in vitro diagnostics',
#   'genetic screening',
#   'clinical laboratory',
#   'pathogen detection',
#   'stem cell therapy',
#   'regenerative medicine',
#   'cellular therapy',
#   'tissue engineering',
#   'stem cell research',
#   'induced pluripotent stem cells',
#   'cell culture',
#   'agricultural biotech',
#   'crop improvement',
#   'genetic modification',
#   'biopesticides',
#   'plant genomics',
#   'sustainable agriculture',
#   'agriculture technology'],
#  ['CRISPR-Cas9',
#   'gene therapy',
#   'genome editing',
#   'targeted gene modification',
#   'genetic disease correction',
#   'next-generation sequencing (NGS)',
#   'whole genome sequencing',
#   'bioinformatics',
#   'genetic analysis',
#   'DNA sequencing technologies',
#   'personalized medicine',
#   'pharmacogenomics',
#   'gene therapies',
#   'cell therapies',
#   'monoclonal antibodies',
#   'regenerative medicine',
#   'genome data analysis',
#   'systems biology',
#   'genetic mapping',
#   'predictive modeling',
#   'AI in genomics',
#   'biologic drugs',
#   'vaccines',
#   'therapeutic proteins',
#   'biosimilars',
#   'drug discovery and development',
#   'GMO crops',
#   'genetic improvement of plants',
#   'biopesticides',
#   'sustainable agriculture',
#   'plant genomics',
#   'bioremediation',
#   'bioenergy',
#   'industrial waste treatment',
#   'environmental monitoring',
#   'green chemistry'],
#  ['electrolysis',
#   'steam methane reforming',
#   'green hydrogen',
#   'blue hydrogen',
#   'hydrogen plants',
#   'renewable energy sources',
#   'liquid hydrogen storage',
#   'metal hydrides',
#   'hydrogen pipelines',
#   'compression and liquefaction',
#   'fueling stations',
#   'proton exchange membrane (PEM) fuel cells',
#   'solid oxide fuel cells',
#   'fuel cell vehicles',
#   'stationary fuel cells',
#   'fuel cell systems',
#   'water electrolysis',
#   'alkaline electrolyzers',
#   'PEM electrolyzers',
#   'solid oxide electrolyzers',
#   'energy conversion',
#   'hydrogen-powered vehicles',
#   'fuel cell electric vehicles (FCEVs)',
#   'buses',
#   'trucks',
#   'rail transport',
#   'aviation',
#   'refining',
#   'ammonia production',
#   'metal processing',
#   'chemical synthesis',
#   'heat and power',
#   'power-to-gas',
#   'hydrogen grids',
#   'renewable energy integration',
#   'energy storage solutions',
#   'grid balancing'],
#  ['smart sensors',
#   'wearables',
#   'home automation devices',
#   'environmental monitoring',
#   'RFID tags',
#   'IoT modules',
#   '5G networks',
#   'WiFi 6',
#   'low-power wide-area networks (LPWAN)',
#   'Zigbee',
#   'Bluetooth Low Energy (BLE)',
#   'satellite IoT',
#   'device management',
#   'data analytics platforms',
#   'cloud IoT services',
#   'IoT security solutions',
#   'edge computing software',
#   'smart thermostats',
#   'security cameras',
#   'voice assistants',
#   'connected appliances',
#   'home energy management',
#   'factory automation',
#   'predictive maintenance',
#   'industrial sensors',
#   'SCADA systems',
#   'industrial cybersecurity',
#   'telematics',
#   'autonomous driving technology',
#   'vehicle-to-everything (V2X) communication',
#   'electric vehicle charging networks',
#   'urban IoT applications',
#   'smart lighting',
#   'traffic management systems',
#   'waste management solutions',
#   'public safety technology',
#   'wearable health devices',
#   'remote patient monitoring',
#   'telehealth platforms',
#   'medical asset tracking',
#   'health data analytics'],
#  ['lithium mines',
#   'brine extraction',
#   'hard rock mining',
#   'lithium carbonate',
#   'lithium hydroxide',
#   'ore processing',
#   'sustainable mining',
#   'mineral processing',
#   'metal purification',
#   'cathode materials',
#   'anode materials',
#   'electrolyte solutions',
#   'battery-grade chemicals',
#   'lithium-ion cells',
#   'cell fabrication',
#   'electrode assembly',
#   'battery cell design',
#   'gigafactories',
#   'cell chemistry',
#   'battery modules',
#   'pack assembly',
#   'thermal management systems',
#   'battery management systems',
#   'high-density battery packs',
#   'battery lifecycle management',
#   'recycling technology',
#   'material recovery',
#   'second-life batteries',
#   'circular economy for batteries',
#   'solid-state batteries',
#   'lithium-sulfur',
#   'energy density improvement',
#   'fast-charging technology',
#   'battery safety innovations',
#   'quality assurance',
#   'performance testing',
#   'safety testing',
#   'certification standards',
#   'regulatory compliance',
#   'endurance testing'],
#  ['imaging systems',
#   'MRI',
#   'CT scans',
#   'X-rays',
#   'ultrasound machines',
#   'blood analysis devices',
#   'surgical instruments',
#   'pacemakers',
#   'stents',
#   'implantable devices',
#   'laser treatments',
#   'dialysis machines',
#   'wearable health monitors',
#   'telemetry devices',
#   'vital signs monitoring equipment',
#   'remote patient monitoring',
#   'artificial joints',
#   'orthotic braces',
#   'prosthetic limbs',
#   'spinal devices',
#   'orthopedic implants',
#   'heart valves',
#   'cardiac rhythm management devices',
#   'angioplasty products',
#   'vascular grafts',
#   'endoscopic systems',
#   'laparoscopic instruments',
#   'robotic surgery devices',
#   'catheters',
#   'centrifuges',
#   'spectrophotometers',
#   'microscopes',
#   'lab automation systems',
#   'reagents and consumables'],
#  ['cloud infrastructure',
#   'SaaS',
#   'PaaS',
#   'IaaS',
#   'cybersecurity',
#   'threat detection',
#   'encryption',
#   'identity management',
#   'secure cloud storage',
#   'data protection',
#   'network security',
#   'vulnerability assessment',
#   'online retail',
#   'e-commerce platform',
#   'shopping cart technology',
#   'payment gateway',
#   'digital wallet',
#   'consumer analytics',
#   'mobile commerce',
#   'e-marketplace',
#   'supply chain management',
#   'online storefront',
#   'user experience design',
#   'data analytics',
#   'machine learning',
#   'AI algorithms',
#   'predictive analytics',
#   'data visualization',
#   'big data platforms',
#   'natural language processing',
#   'deep learning',
#   'AI models',
#   'neural networks',
#   'cognitive computing',
#   'mobile applications',
#   '5G technology',
#   'wireless networks',
#   'IoT devices',
#   'smart home technology',
#   'wearable tech',
#   'connected vehicles',
#   'IoT security',
#   'IoT platforms',
#   'edge computing',
#   'sensor networks',
#   'social networking',
#   'user-generated content',
#   'digital media',
#   'social advertising',
#   'viral marketing',
#   'content sharing',
#   'engagement metrics',
#   'influencer platforms',
#   'community engagement',
#   'online identity',
#   'privacy controls',
#   'blockchain systems',
#   'distributed ledger',
#   'cryptocurrency',
#   'tokenization',
#   'digital assets',
#   'smart contracts',
#   'P2P lending',
#   'blockchain security',
#   'decentralization',
#   'non-fungible tokens',
#   'crypto exchanges'],
#  ['wind farms',
#   'turbines',
#   'offshore wind',
#   'wind power generation',
#   'wind energy technology',
#   'photovoltaic systems',
#   'solar farms',
#   'rooftop solar',
#   'solar power plants',
#   'solar panel manufacturing',
#   'hydro plants',
#   'dams',
#   'run-of-river systems',
#   'pumped storage',
#   'hydro turbines',
#   'geothermal plants',
#   'heat extraction',
#   'geothermal wells',
#   'steam turbines',
#   'geothermal heating and cooling',
#   'biomass energy',
#   'biofuel production',
#   'biogas',
#   'biodiesel',
#   'ethanol',
#   'waste-to-energy plants'],
#  ['industrial robots',
#   'automation solutions',
#   'manufacturing robots',
#   'assembly line automation',
#   'robotic arms',
#   'factory automation',
#   'production efficiency',
#   'AI algorithms',
#   'machine learning models',
#   'deep learning frameworks',
#   'natural language processing software',
#   'AI application development',
#   'neural networks',
#   'data analytics AI',
#   'surgical robots',
#   'minimally invasive surgery',
#   'robotic surgery systems',
#   'medical robotics',
#   'surgical automation',
#   'patient recovery time',
#   'precision surgery',
#   'self-driving cars',
#   'autonomous driving technology',
#   'driverless transportation',
#   'vehicle AI',
#   'lidar technology',
#   'navigation systems',
#   'electric autonomous vehicles',
#   'unmanned aerial vehicles',
#   'drone navigation systems',
#   'aerial surveillance',
#   'drone photography',
#   'delivery drones',
#   'quadcopters',
#   'remote sensing',
#   'home automation robots',
#   'cleaning robots',
#   'personal assistant robots',
#   'security robots',
#   'smart appliances',
#   'robotic lawn mowers',
#   'voice-activated devices',
#   'fintech AI',
#   'algorithmic trading',
#   'financial analytics',
#   'robo-advisors',
#   'fraud detection AI',
#   'personalized banking services',
#   'credit risk assessment',
#   'speech recognition',
#   'language translation',
#   'sentiment analysis',
#   'chatbots',
#   'text-to-speech',
#   'conversational AI',
#   'content generation AI',
#   'diagnostic algorithms',
#   'predictive analytics in healthcare',
#   'medical image analysis',
#   'patient data analysis',
#   'AI in radiology',
#   'telehealth AI',
#   'personal robots',
#   'educational robots',
#   'entertainment robots',
#   'wearable AI devices',
#   'interactive toys',
#   'robotics kits',
#   'consumer drone technology'],
#  ['foundry services',
#   'chip manufacturing',
#   'wafer processing',
#   'photolithography',
#   'cleanroom technology',
#   'semiconductor fabrication plants',
#   'integrated circuit design',
#   'CAD for electronics',
#   'microarchitecture',
#   'system-on-chip (SoC)',
#   'electronic design automation (EDA)',
#   'semiconductor machinery',
#   'fabrication equipment',
#   'testing equipment',
#   'silicon wafers',
#   'chemicals and gases for semiconductor production',
#   'CPU design',
#   'graphics processors',
#   'chipsets',
#   'performance computing',
#   'central processing units',
#   'mobile processors',
#   'DRAM',
#   'SSDs',
#   'flash memory',
#   'memory chips',
#   'non-volatile memory',
#   'data storage solutions',
#   'supply chain logistics',
#   'electronic component distribution',
#   'B2B semiconductor sales',
#   'inventory management',
#   'nanoelectronics',
#   'quantum dots',
#   'semiconductor lasers',
#   'power semiconductors',
#   'high-electron-mobility transistors'],
#  ['solar panels',
#   'photovoltaic cells',
#   'silicon wafers',
#   'thin-film solar cells',
#   'solar module assembly',
#   'efficiency improvements',
#   'solar farms',
#   'rooftop solar installations',
#   'utility-scale solar',
#   'solar power plants',
#   'feed-in tariffs',
#   'power purchase agreements (PPAs)',
#   'solar batteries',
#   'energy storage systems',
#   'grid integration',
#   'charge controllers',
#   'off-grid solar solutions',
#   'solar water heating',
#   'concentrated solar power (CSP)',
#   'solar thermal collectors',
#   'parabolic troughs',
#   'solar towers',
#   'solar lighting',
#   'portable solar chargers',
#   'solar-powered appliances',
#   'building-integrated photovoltaics (BIPV)',
#   'smart grids',
#   'net metering',
#   'microgrids',
#   'renewable energy integration',
#   'solar energy management systems',
#   'next-generation photovoltaics',
#   'perovskite solar cells',
#   'organic photovoltaic cells (OPVs)',
#   'solar efficiency research',
#   'innovative solar materials'],
#  ['satellite communications',
#   'space station',
#   'orbital launch vehicles',
#   'satellite manufacturing',
#   'space exploration',
#   'space tourism',
#   'earth observation',
#   'suborbital flights',
#   'space tourism',
#   'research platforms',
#   'suborbital transportation',
#   'reusable launch vehicles',
#   'rocket propulsion',
#   'space-grade materials',
#   'aerospace engineering',
#   'navigation technology',
#   'life support systems',
#   'space suits',
#   'avionics',
#   'terrestrial networks',
#   'space-based internet',
#   'space law',
#   'remote sensing',
#   'global positioning system',
#   'space-based research',
#   'aerospace investment'],
#  ['virtual consultations',
#   'remote patient monitoring',
#   'telehealth platforms',
#   'e-prescriptions',
#   'video conferencing healthcare',
#   'online medical services',
#   'big data in healthcare',
#   'predictive analytics',
#   'health informatics',
#   'electronic health records (EHR)',
#   'clinical decision support',
#   'patient data analysis',
#   'wearable health monitors',
#   'IoT medical devices',
#   'smart health devices',
#   'remote diagnostic equipment',
#   'health tracking apps',
#   'medical billing automation',
#   'health care IT solutions',
#   'electronic medical records (EMR) systems',
#   'practice management software',
#   'health care administration',
#   'software as a medical device',
#   'app-based health interventions',
#   'digital treatment platforms',
#   'cognitive behavioral therapy apps',
#   'mHealth apps',
#   'fitness tracking',
#   'lifestyle management apps',
#   'medication adherence apps',
#   'patient engagement applications',
#   'health data encryption',
#   'HIPAA-compliant platforms',
#   'cybersecurity in healthcare',
#   'patient privacy technology',
#   'secure health data exchange'],
#  ['game design',
#   'game engines',
#   'indie games',
#   'AAA titles',
#   'mobile gaming',
#   'cross-platform development',
#   'competitive gaming',
#   'esports tournaments',
#   'professional teams',
#   'live streaming events',
#   'esports arenas',
#   'online gaming platforms',
#   'digital distribution',
#   'game streaming services',
#   'multiplayer servers',
#   'gaming communities',
#   'gaming consoles',
#   'PC gaming rigs',
#   'gaming peripherals',
#   'VR headsets',
#   'custom controllers',
#   'high-performance hardware',
#   'VR gaming experiences',
#   'AR mobile games',
#   'immersive technology',
#   'mixed reality',
#   'VR content development',
#   'game streaming',
#   'content creators',
#   'live game broadcasts',
#   'video game vlogging',
#   'streaming platforms',
#   'player data analysis',
#   'gaming trends',
#   'user experience research',
#   'engagement metrics',
#   'in-game advertising'],
#  ['turbine design',
#   'blade manufacturing',
#   'nacelle assembly',
#   'offshore turbines',
#   'onshore wind turbines',
#   'turbine components',
#   'site assessment',
#   'wind farm construction',
#   'project management',
#   'operations and maintenance',
#   'wind power generation',
#   'battery storage',
#   'grid integration',
#   'energy management systems',
#   'power-to-grid solutions',
#   'storage technology',
#   'offshore wind farms',
#   'floating turbines',
#   'marine engineering',
#   'installation vessels',
#   'seabed surveying',
#   'electrical infrastructure',
#   'substations',
#   'transmission lines',
#   'grid connection',
#   'wind measurement systems',
#   'vertical axis turbines',
#   'wind energy software',
#   'performance optimization',
#   'aerodynamics analysis',
#   'remote sensing technologies',
#   'feasibility studies',
#   'environmental impact assessments',
#   'wind resource analysis',
#   'technical advisory',
#   'project financing']]

# %%
industry_list_golden
# Out:
# [['Commercial Aircraft Manufacturing',
#   'Military Aircraft and Systems',
#   'Space Systems and Exploration',
#   'Defense Equipment and Armaments',
#   'Aerospace Components and Systems',
#   'Unmanned Aerial Vehicles (UAVs)',
#   'Aerospace Maintenance and Services'],
#  ['Senior Healthcare Services',
#   'Assisted Living Facilities',
#   'Pharmaceutical Development for Age-Related Diseases',
#   'Medical Devices for Seniors',
#   'Nutritional Supplements and Health Foods',
#   'Financial Services for Seniors',
#   'Age-Friendly Products and Services'],
#  ['Autonomous Transportation',
#   'Robotics and Automation',
#   '3D Printing',
#   'Energy Storage',
#   'Space Exploration'],
#  ['Pharmaceutical Biotechnology',
#   'Agricultural Biotechnology',
#   'Industrial Biotechnology',
#   'Environmental Biotechnology',
#   'Medical Devices and Diagnostics',
#   'Genomics and Proteomics',
#   'Bioinformatics and Data Analysis'],
#  ['Cryptocurrency Exchanges',
#   'Blockchain Development Platforms',
#   'Decentralized Finance (DeFi)',
#   'Digital Asset Management',
#   'Smart Contract Services',
#   'Blockchain in Supply Chain',
#   'Crypto Mining Infrastructure'],
#  ['Solar Power Generation',
#   'Wind Power Generation',
#   'Hydroelectric Power',
#   'Biomass Energy',
#   'Geothermal Energy',
#   'Tidal and Wave Energy',
#   'Energy Storage Solutions'],
#  ['Infrastructure-as-a-Service (IaaS)',
#   'Platform-as-a-Service (PaaS)',
#   'Software-as-a-Service (SaaS)',
#   'Data Center REITs',
#   'Cloud Security and Compliance',
#   'Edge Computing'],
#  ['Network Security',
#   'Endpoint Security',
#   'Identity and Access Management',
#   'Cloud Security',
#   'Data Security and Encryption',
#   'Threat Intelligence and Response',
#   'Application Security'],
#  ['Data Center Real Estate Investment Trusts (REITs)',
#   'Network Infrastructure Providers',
#   'Cloud Data Centers',
#   'Edge Data Centers',
#   'Digital Infrastructure Services',
#   'Connectivity Solutions',
#   'Data Center Design and Construction'],
#  ['Transaction Innovations',
#   'Blockchain Technology',
#   'Risk Transformation',
#   'Frictionless Funding Platforms',
#   'Customer Facing Platforms',
#   'New Intermediaries'],
#  ['CRISPR',
#   'Targeted Therapeutics',
#   'Bioinformatics',
#   'Molecular Diagnostics',
#   'Stem Cells',
#   'Agricultural Biology'],
#  ['Gene Editing and CRISPR',
#   'Genomic Sequencing',
#   'Genetic Medicine and Therapy',
#   'Computational Genomics',
#   'Biopharmaceuticals',
#   'Agricultural Biotechnology',
#   'Environmental Biotechnology'],
#  ['Hydrogen Production and Generation',
#   'Hydrogen Storage and Distribution',
#   'Fuel Cell Technology',
#   'Electrolyzers',
#   'Hydrogen in Transport',
#   'Hydrogen for Industrial Use',
#   'Hydrogen Energy Systems Integration'],
#  ['IoT Devices and Sensors',
#   'IoT Connectivity Solutions',
#   'IoT Platforms and Software',
#   'Smart Home Technology',
#   'Industrial IoT (IIoT)',
#   'Connected Vehicles and Transportation',
#   'Smart City and Infrastructure',
#   'Healthcare IoT'],
#  ['Lithium Mining and Extraction',
#   'Battery Materials Refinement',
#   'Battery Cell Manufacturing',
#   'Battery Pack Assembly',
#   'Battery Recycling and Repurposing',
#   'Advanced Battery Technologies',
#   'Battery Testing and Certification'],
#  ['Diagnostic Equipment',
#   'Therapeutic Devices',
#   'Patient Monitoring Systems',
#   'Orthopedic and Prosthetic Devices',
#   'Cardiovascular Devices',
#   'Minimally Invasive Surgical Devices',
#   'Laboratory Equipment'],
#  ['Cloud Computing & Cyber Security',
#   'E-Commerce',
#   'Big Data & Artificial Intelligence (AI)',
#   'Mobile Technology and Internet of Things',
#   'Social Platforms',
#   'Blockchain & P2P'],
#  ['Wind Energy Production',
#   'Solar Energy Production',
#   'Hydroelectric Power',
#   'Geothermal Energy',
#   'Bioenergy and Biofuels'],
#  ['Industrial Automation Robotics',
#   'AI Software and Algorithms',
#   'Robot-Assisted Surgery',
#   'Autonomous Vehicles',
#   'Drone Technology',
#   'Smart Home Robotics',
#   'AI in Financial Services',
#   'Natural Language Processing (NLP)',
#   'AI in Healthcare Diagnostics',
#   'Consumer Robotics'],
#  ['Semiconductor Fabrication',
#   'Semiconductor Design',
#   'Semiconductor Equipment and Materials',
#   'Microprocessors and Chipsets',
#   'Memory and Storage Technology',
#   'Semiconductor Distribution',
#   'Advanced Semiconductor Technologies'],
#  ['Solar Photovoltaic (PV) Manufacturing',
#   'Solar Power Generation',
#   'Solar Energy Storage Solutions',
#   'Solar Thermal Technology',
#   'Solar Products and Applications',
#   'Integration of Solar into Energy Systems',
#   'Research and Development in Solar Technology'],
#  ['Orbital Aerospace',
#   'Suborbital Aerospace',
#   'Enabling Technologies',
#   'Aerospace Beneficiary'],
#  ['Telemedicine Services',
#   'Health Care Analytics',
#   'Connected Health Care Devices',
#   'Administrative Digitization',
#   'Digital Therapeutics',
#   'Mobile Health Applications',
#   'Health Data Security'],
#  ['Game Development and Publishing',
#   'Esports Leagues and Competitions',
#   'Gaming Platforms and Services',
#   'Gaming Hardware and Accessories',
#   'Virtual and Augmented Reality Gaming',
#   'Content Creation and Streaming',
#   'Game Analytics and User Engagement'],
#  ['Wind Turbine Manufacturing',
#   'Wind Farm Development and Operation',
#   'Wind Energy Storage Solutions',
#   'Offshore Wind Energy',
#   'Wind Energy Infrastructure',
#   'Advanced Wind Technologies',
#   'Wind Energy Consulting and Services']]

# %%
def find_ind_keywords(context,my_question):
  print(f"Industries: {industry_list}")
  print(f"Keywords: {keyword_list}")
  context=context
  pred= ThemeToIndustry()(context=context,question=my_question)
  industry_list.append(pred.industries)
  keyword_list.append(pred.keywords)
  return industry_list,keyword_list

# %%
# Ask any question you like to this simple RAG program.
my_question = "Generate seven to fifteen sub-industries that give exposure\
                          to companies associated with the investment theme provided in context."
industry_list=[]
keyword_list=[]
for context in theme_list:
  industry_list,keyword_list=find_ind_keywords(context,my_question)
# Out:
# Industries: []
# Keywords: []
# Industries: [['Integrated Circuits', 'Memory Chips', 'Microprocessors', 'Analog Semiconductors', 'Semiconductor Equipment', 'Semiconductor Materials', 'LED Semiconductors', 'Power Management Semiconductors', 'RF Semiconductors', ' Image Sensors', ' Display Drivers', ' System-on-Chip (SoC)', ' Field-Programmable Gate Arrays (FPGAs)', ' Optoelectronics']]
# Keywords: [['Microprocessors', 'Memory chips', 'Analog circuits', 'Digital circuits', 'System-on-chip (SoC)', 'Field-programmable gate arrays (FPGAs)', 'Application-specific integrated circuits (ASICs)', 'Semiconductor fabrication', 'Silicon wafer', ' Semiconductor packaging', 'DRAM (Dynamic Random Access Memory)', 'NAND (Negative-AND) Flash', 'Memory chip manufacturers', 'Semiconductor industry', 'Data storage solutions', 'AI (Artificial Intelligence) applications', 'IoT (Internet of Things) devices', 'Market demand for memory chips', 'Supply chain management', ' Emerging technologies in memory chips', 'CPU (Central Processing Unit)', 'Silicon chips', "Moore's Law", 'Semiconductor industry', 'Data processing', 'Integrated circuits', 'Chip design', 'Performance optimization', 'Nanotechnology', ' Artificial intelligence (AI) applications', 'Operational amplifiers', 'Voltage regulators', 'Analog-to-digital converters', 'Signal processing', 'Power management', 'Data acquisition', 'Mixed-signal', 'Low-power design', 'Precision analog', ' Sensor interfaces', 'Lithography', 'Etching', 'Deposition', 'Metrology', 'Wafer handling', 'Cleanroom technology', 'Chemical mechanical polishing', 'Ion implantation', 'Rapid thermal processing', ' Plasma processing', 'Silicon', 'Gallium nitride', 'Silicon carbide', 'III-V compounds', 'Wafer fabrication', 'Thin film deposition', 'Chemical vapor deposition', 'Atomic layer deposition', 'Semiconductor packaging', ' Dielectric materials', 'LED chips', 'Solid-state lighting', 'Energy efficiency', 'Automotive lighting', 'Display technology', 'UV LEDs', 'Smart lighting', 'Horticultural lighting', 'Mini LED', ' OLED lighting', 'Voltage Regulators', 'Power ICs', 'DC-DC Converters', 'Power MOSFETs', 'Energy Efficiency', 'Power Supply Units', 'Battery Management', 'Power Consumption', 'Thermal Management', ' Power Semiconductor Devices', 'RF Power Amplifiers', 'RF Filters', 'RF Transceivers', 'GaN Semiconductors', 'RF Front-End Modules', 'Wireless Communication', '5G Technology', 'IoT Devices', 'Satellite Communication', ' Radar Systems', 'CMOS image sensors', 'CCD image sensors', 'Automotive image sensors', 'Smartphone image sensors', 'Machine vision sensors', '3D image sensors', 'Global image sensors market', 'Sony image sensors', 'Samsung image sensors', ' Emerging image sensor technologies', 'LCD display drivers', 'OLED display drivers', 'TFT display drivers', 'LED display drivers', 'Display driver ICs', 'Touchscreen display drivers', 'Automotive display drivers', 'Mobile display drivers', 'Display driver market', ' Display driver technology', 'Integrated Circuits', 'Embedded Systems', 'IoT Devices', 'Mobile Devices', 'Artificial Intelligence', 'Power Management', 'Wireless Communication', 'Automotive Electronics', 'Consumer Electronics', ' Semiconductor Manufacturing', 'Programmable Logic Devices', 'FPGA Design', 'Hardware Acceleration', 'Reconfigurable Computing', 'FPGA Development Tools', 'High Performance Computing', 'FPGA Prototyping', 'Embedded Systems', 'Digital Signal Processing', ' FPGA Market Trends', 'Light-emitting diodes (LEDs)', 'Photodetectors', 'Optical fibers', 'Laser diodes', 'Optoelectronic sensors', 'Display technologies', 'Photovoltaic cells', 'Fiber optics', 'Semiconductor lasers', ' Optoelectronic devices']]
# Industries: [['Integrated Circuits', 'Memory Chips', 'Microprocessors', 'Analog Semiconductors', 'Semiconductor Equipment', 'Semiconductor Materials', 'LED Semiconductors', 'Power Management Semiconductors', 'RF Semiconductors', ' Image Sensors', ' Display Drivers', ' System-on-Chip (SoC)', ' Field-Programmable Gate Arrays (FPGAs)', ' Optoelectronics'], ['Solar panel manufacturing', 'Solar inverter manufacturing', 'Solar mounting and racking systems', 'Solar tracking technology', 'Solar energy storage solutions', 'Solar project development', 'Solar installation services', 'Solar financing and leasing', 'Solar monitoring and maintenance', ' Solar software and analytics', ' Solar microgrid systems', ' Solar thermal technology', ' Solar electric vehicle charging stations', ' Solar-powered water desalination', ' Solar-powered agriculture solutions']]
# Keywords: [['Microprocessors', 'Memory chips', 'Analog circuits', 'Digital circuits', 'System-on-chip (SoC)', 'Field-programmable gate arrays (FPGAs)', 'Application-specific integrated circuits (ASICs)', 'Semiconductor fabrication', 'Silicon wafer', ' Semiconductor packaging', 'DRAM (Dynamic Random Access Memory)', 'NAND (Negative-AND) Flash', 'Memory chip manufacturers', 'Semiconductor industry', 'Data storage solutions', 'AI (Artificial Intelligence) applications', 'IoT (Internet of Things) devices', 'Market demand for memory chips', 'Supply chain management', ' Emerging technologies in memory chips', 'CPU (Central Processing Unit)', 'Silicon chips', "Moore's Law", 'Semiconductor industry', 'Data processing', 'Integrated circuits', 'Chip design', 'Performance optimization', 'Nanotechnology', ' Artificial intelligence (AI) applications', 'Operational amplifiers', 'Voltage regulators', 'Analog-to-digital converters', 'Signal processing', 'Power management', 'Data acquisition', 'Mixed-signal', 'Low-power design', 'Precision analog', ' Sensor interfaces', 'Lithography', 'Etching', 'Deposition', 'Metrology', 'Wafer handling', 'Cleanroom technology', 'Chemical mechanical polishing', 'Ion implantation', 'Rapid thermal processing', ' Plasma processing', 'Silicon', 'Gallium nitride', 'Silicon carbide', 'III-V compounds', 'Wafer fabrication', 'Thin film deposition', 'Chemical vapor deposition', 'Atomic layer deposition', 'Semiconductor packaging', ' Dielectric materials', 'LED chips', 'Solid-state lighting', 'Energy efficiency', 'Automotive lighting', 'Display technology', 'UV LEDs', 'Smart lighting', 'Horticultural lighting', 'Mini LED', ' OLED lighting', 'Voltage Regulators', 'Power ICs', 'DC-DC Converters', 'Power MOSFETs', 'Energy Efficiency', 'Power Supply Units', 'Battery Management', 'Power Consumption', 'Thermal Management', ' Power Semiconductor Devices', 'RF Power Amplifiers', 'RF Filters', 'RF Transceivers', 'GaN Semiconductors', 'RF Front-End Modules', 'Wireless Communication', '5G Technology', 'IoT Devices', 'Satellite Communication', ' Radar Systems', 'CMOS image sensors', 'CCD image sensors', 'Automotive image sensors', 'Smartphone image sensors', 'Machine vision sensors', '3D image sensors', 'Global image sensors market', 'Sony image sensors', 'Samsung image sensors', ' Emerging image sensor technologies', 'LCD display drivers', 'OLED display drivers', 'TFT display drivers', 'LED display drivers', 'Display driver ICs', 'Touchscreen display drivers', 'Automotive display drivers', 'Mobile display drivers', 'Display driver market', ' Display driver technology', 'Integrated Circuits', 'Embedded Systems', 'IoT Devices', 'Mobile Devices', 'Artificial Intelligence', 'Power Management', 'Wireless Communication', 'Automotive Electronics', 'Consumer Electronics', ' Semiconductor Manufacturing', 'Programmable Logic Devices', 'FPGA Design', 'Hardware Acceleration', 'Reconfigurable Computing', 'FPGA Development Tools', 'High Performance Computing', 'FPGA Prototyping', 'Embedded Systems', 'Digital Signal Processing', ' FPGA Market Trends', 'Light-emitting diodes (LEDs)', 'Photodetectors', 'Optical fibers', 'Laser diodes', 'Optoelectronic sensors', 'Display technologies', 'Photovoltaic cells', 'Fiber optics', 'Semiconductor lasers', ' Optoelectronic devices'], ['Photovoltaic cells', 'Silicon wafers', 'Solar module assembly', 'Thin-film technology', 'Solar panel efficiency', 'Solar panel production', 'Solar energy industry', 'Renewable energy technology', 'Solar panel market', ' Solar panel installation', 'Photovoltaic (PV) inverters', 'Grid-tied inverters', 'Off-grid inverters', 'Microinverters', 'String inverters', 'Power electronics', 'Renewable energy', 'Energy storage', 'Smart grid integration', ' Efficiency optimization', 'Photovoltaic mounting systems', 'Ground mount solar racking', 'Roof mount solar systems', 'Solar panel mounting hardware', 'Solar array racking solutions', 'Fixed tilt solar mounts', 'Tracking solar racking sy ...
# Industries: [['Integrated Circuits', 'Memory Chips', 'Microprocessors', 'Analog Semiconductors', 'Semiconductor Equipment', 'Semiconductor Materials', 'LED Semiconductors', 'Power Management Semiconductors', 'RF Semiconductors', ' Image Sensors', ' Display Drivers', ' System-on-Chip (SoC)', ' Field-Programmable Gate Arrays (FPGAs)', ' Optoelectronics'], ['Solar panel manufacturing', 'Solar inverter manufacturing', 'Solar mounting and racking systems', 'Solar tracking technology', 'Solar energy storage solutions', 'Solar project development', 'Solar installation services', 'Solar financing and leasing', 'Solar monitoring and maintenance', ' Solar software and analytics', ' Solar microgrid systems', ' Solar thermal technology', ' Solar electric vehicle charging stations', ' Solar-powered water desalination', ' Solar-powered agriculture solutions'], ['Satellite manufacturing', 'Rocket propulsion systems', 'Space tourism', 'Space mining', 'Satellite communication services', 'Space debris removal', 'Space habitat construction', 'Space agriculture', 'Space-based research and development', ' Space launch services', ' Space navigation and positioning systems', ' Space exploration robotics', ' Space-based imaging and remote sensing', ' Space weather forecasting', ' Space law and regulations']]
# Keywords: [['Microprocessors', 'Memory chips', 'Analog circuits', 'Digital circuits', 'System-on-chip (SoC)', 'Field-programmable gate arrays (FPGAs)', 'Application-specific integrated circuits (ASICs)', 'Semiconductor fabrication', 'Silicon wafer', ' Semiconductor packaging', 'DRAM (Dynamic Random Access Memory)', 'NAND (Negative-AND) Flash', 'Memory chip manufacturers', 'Semiconductor industry', 'Data storage solutions', 'AI (Artificial Intelligence) applications', 'IoT (Internet of Things) devices', 'Market demand for memory chips', 'Supply chain management', ' Emerging technologies in memory chips', 'CPU (Central Processing Unit)', 'Silicon chips', "Moore's Law", 'Semiconductor industry', 'Data processing', 'Integrated circuits', 'Chip design', 'Performance optimization', 'Nanotechnology', ' Artificial intelligence (AI) applications', 'Operational amplifiers', 'Voltage regulators', 'Analog-to-digital converters', 'Signal processing', 'Power management', 'Data acquisition', 'Mixed-signal', 'Low-power design', 'Precision analog', ' Sensor interfaces', 'Lithography', 'Etching', 'Deposition', 'Metrology', 'Wafer handling', 'Cleanroom technology', 'Chemical mechanical polishing', 'Ion implantation', 'Rapid thermal processing', ' Plasma processing', 'Silicon', 'Gallium nitride', 'Silicon carbide', 'III-V compounds', 'Wafer fabrication', 'Thin film deposition', 'Chemical vapor deposition', 'Atomic layer deposition', 'Semiconductor packaging', ' Dielectric materials', 'LED chips', 'Solid-state lighting', 'Energy efficiency', 'Automotive lighting', 'Display technology', 'UV LEDs', 'Smart lighting', 'Horticultural lighting', 'Mini LED', ' OLED lighting', 'Voltage Regulators', 'Power ICs', 'DC-DC Converters', 'Power MOSFETs', 'Energy Efficiency', 'Power Supply Units', 'Battery Management', 'Power Consumption', 'Thermal Management', ' Power Semiconductor Devices', 'RF Power Amplifiers', 'RF Filters', 'RF Transceivers', 'GaN Semiconductors', 'RF Front-End Modules', 'Wireless Communication', '5G Technology', 'IoT Devices', 'Satellite Communication', ' Radar Systems', 'CMOS image sensors', 'CCD image sensors', 'Automotive image sensors', 'Smartphone image sensors', 'Machine vision sensors', '3D image sensors', 'Global image sensors market', 'Sony image sensors', 'Samsung image sensors', ' Emerging image sensor technologies', 'LCD display drivers', 'OLED display drivers', 'TFT display drivers', 'LED display drivers', 'Display driver ICs', 'Touchscreen display drivers', 'Automotive display drivers', 'Mobile display drivers', 'Display driver market', ' Display driver technology', 'Integrated Circuits', 'Embedded Systems', 'IoT Devices', 'Mobile Devices', 'Artificial Intelligence', 'Power Management', 'Wireless Communication', 'Automotive Electronics', 'Consumer Electronics', ' Semiconductor Manufacturing', 'Programmable Logic Devices', 'FPGA Design', 'Hardware Acceleration', 'Reconfigurable Computing', 'FPGA Development Tools', 'High Performance Computing', 'FPGA Prototyping', 'Embedded Systems', 'Digital Signal Processing', ' FPGA Market Trends', 'Light-emitting diodes (LEDs)', 'Photodetectors', 'Optical fibers', 'Laser diodes', 'Optoelectronic sensors', 'Display technologies', 'Photovoltaic cells', 'Fiber optics', 'Semiconductor lasers', ' Optoelectronic devices'], ['Photovoltaic cells', 'Silicon wafers', 'Solar module assembly', 'Thin-film technology', 'Solar panel efficiency', 'Solar panel production', 'Solar energy industry', 'Renewable energy technology', 'Solar panel market', ' Solar panel installation', 'Photovoltaic (PV) inverters', 'Grid-tied inverters', 'Off-grid inverters', 'Microinverters', 'String inverters', 'Power electronics', 'Renewable energy', 'Energy storage', 'Smart grid integration', ' Efficiency optimization', 'Photovoltaic mounting systems', 'Ground mount solar racking', 'Roof mount solar systems', 'Solar panel mounting hardware', 'Solar array racking solutions', 'Fixed tilt solar mounts', 'Tracking solar racking sy ...
# Industries: [['Integrated Circuits', 'Memory Chips', 'Microprocessors', 'Analog Semiconductors', 'Semiconductor Equipment', 'Semiconductor Materials', 'LED Semiconductors', 'Power Management Semiconductors', 'RF Semiconductors', ' Image Sensors', ' Display Drivers', ' System-on-Chip (SoC)', ' Field-Programmable Gate Arrays (FPGAs)', ' Optoelectronics'], ['Solar panel manufacturing', 'Solar inverter manufacturing', 'Solar mounting and racking systems', 'Solar tracking technology', 'Solar energy storage solutions', 'Solar project development', 'Solar installation services', 'Solar financing and leasing', 'Solar monitoring and maintenance', ' Solar software and analytics', ' Solar microgrid systems', ' Solar thermal technology', ' Solar electric vehicle charging stations', ' Solar-powered water desalination', ' Solar-powered agriculture solutions'], ['Satellite manufacturing', 'Rocket propulsion systems', 'Space tourism', 'Space mining', 'Satellite communication services', 'Space debris removal', 'Space habitat construction', 'Space agriculture', 'Space-based research and development', ' Space launch services', ' Space navigation and positioning systems', ' Space exploration robotics', ' Space-based imaging and remote sensing', ' Space weather forecasting', ' Space law and regulations'], ['Telehealth platforms', 'Remote patient monitoring devices', 'Health information exchange platforms', 'Virtual care services', 'Digital therapeutics', 'Wearable health technology', 'Telemedicine software providers', 'Teleconsultation services', 'Telepsychiatry services', ' Remote diagnostics', ' Telemedicine infrastructure providers', ' Telemedicine training and education platforms', ' Telemedicine billing and reimbursement solutions', ' Telemedicine regulatory compliance services', ' Telemedicine cybersecurity solutions']]
# Keywords: [['Microprocessors', 'Memory chips', 'Analog circuits', 'Digital circuits', 'System-on-chip (SoC)', 'Field-programmable gate arrays (FPGAs)', 'Application-specific integrated circuits (ASICs)', 'Semiconductor fabrication', 'Silicon wafer', ' Semiconductor packaging', 'DRAM (Dynamic Random Access Memory)', 'NAND (Negative-AND) Flash', 'Memory chip manufacturers', 'Semiconductor industry', 'Data storage solutions', 'AI (Artificial Intelligence) applications', 'IoT (Internet of Things) devices', 'Market demand for memory chips', 'Supply chain management', ' Emerging technologies in memory chips', 'CPU (Central Processing Unit)', 'Silicon chips', "Moore's Law", 'Semiconductor industry', 'Data processing', 'Integrated circuits', 'Chip design', 'Performance optimization', 'Nanotechnology', ' Artificial intelligence (AI) applications', 'Operational amplifiers', 'Voltage regulators', 'Analog-to-digital converters', 'Signal processing', 'Power management', 'Data acquisition', 'Mixed-signal', 'Low-power design', 'Precision analog', ' Sensor interfaces', 'Lithography', 'Etching', 'Deposition', 'Metrology', 'Wafer handling', 'Cleanroom technology', 'Chemical mechanical polishing', 'Ion implantation', 'Rapid thermal processing', ' Plasma processing', 'Silicon', 'Gallium nitride', 'Silicon carbide', 'III-V compounds', 'Wafer fabrication', 'Thin film deposition', 'Chemical vapor deposition', 'Atomic layer deposition', 'Semiconductor packaging', ' Dielectric materials', 'LED chips', 'Solid-state lighting', 'Energy efficiency', 'Automotive lighting', 'Display technology', 'UV LEDs', 'Smart lighting', 'Horticultural lighting', 'Mini LED', ' OLED lighting', 'Voltage Regulators', 'Power ICs', 'DC-DC Converters', 'Power MOSFETs', 'Energy Efficiency', 'Power Supply Units', 'Battery Management', 'Power Consumption', 'Thermal Management', ' Power Semiconductor Devices', 'RF Power Amplifiers', 'RF Filters', 'RF Transceivers', 'GaN Semiconductors', 'RF Front-End Modules', 'Wireless Communication', '5G Technology', 'IoT Devices', 'Satellite Communication', ' Radar Systems', 'CMOS image sensors', 'CCD image sensors', 'Automotive image sensors', 'Smartphone image sensors', 'Machine vision sensors', '3D image sensors', 'Global image sensors market', 'Sony image sensors', 'Samsung image sensors', ' Emerging image sensor technologies', 'LCD display drivers', 'OLED display drivers', 'TFT display drivers', 'LED display drivers', 'Display driver ICs', 'Touchscreen display drivers', 'Automotive display drivers', 'Mobile display drivers', 'Display driver market', ' Display driver technology', 'Integrated Circuits', 'Embedded Systems', 'IoT Devices', 'Mobile Devices', 'Artificial Intelligence', 'Power Management', 'Wireless Communication', 'Automotive Electronics', 'Consumer Electronics', ' Semiconductor Manufacturing', 'Programmable Logic Devices', 'FPGA Design', 'Hardware Acceleration', 'Reconfigurable Computing', 'FPGA Development Tools', 'High Performance Computing', 'FPGA Prototyping', 'Embedded Systems', 'Digital Signal Processing', ' FPGA Market Trends', 'Light-emitting diodes (LEDs)', 'Photodetectors', 'Optical fibers', 'Laser diodes', 'Optoelectronic sensors', 'Display technologies', 'Photovoltaic cells', 'Fiber optics', 'Semiconductor lasers', ' Optoelectronic devices'], ['Photovoltaic cells', 'Silicon wafers', 'Solar module assembly', 'Thin-film technology', 'Solar panel efficiency', 'Solar panel production', 'Solar energy industry', 'Renewable energy technology', 'Solar panel market', ' Solar panel installation', 'Photovoltaic (PV) inverters', 'Grid-tied inverters', 'Off-grid inverters', 'Microinverters', 'String inverters', 'Power electronics', 'Renewable energy', 'Energy storage', 'Smart grid integration', ' Efficiency optimization', 'Photovoltaic mounting systems', 'Ground mount solar racking', 'Roof mount solar systems', 'Solar panel mounting hardware', 'Solar array racking solutions', 'Fixed tilt solar mounts', 'Tracking solar racking sy ...
# Industries: [['Integrated Circuits', 'Memory Chips', 'Microprocessors', 'Analog Semiconductors', 'Semiconductor Equipment', 'Semiconductor Materials', 'LED Semiconductors', 'Power Management Semiconductors', 'RF Semiconductors', ' Image Sensors', ' Display Drivers', ' System-on-Chip (SoC)', ' Field-Programmable Gate Arrays (FPGAs)', ' Optoelectronics'], ['Solar panel manufacturing', 'Solar inverter manufacturing', 'Solar mounting and racking systems', 'Solar tracking technology', 'Solar energy storage solutions', 'Solar project development', 'Solar installation services', 'Solar financing and leasing', 'Solar monitoring and maintenance', ' Solar software and analytics', ' Solar microgrid systems', ' Solar thermal technology', ' Solar electric vehicle charging stations', ' Solar-powered water desalination', ' Solar-powered agriculture solutions'], ['Satellite manufacturing', 'Rocket propulsion systems', 'Space tourism', 'Space mining', 'Satellite communication services', 'Space debris removal', 'Space habitat construction', 'Space agriculture', 'Space-based research and development', ' Space launch services', ' Space navigation and positioning systems', ' Space exploration robotics', ' Space-based imaging and remote sensing', ' Space weather forecasting', ' Space law and regulations'], ['Telehealth platforms', 'Remote patient monitoring devices', 'Health information exchange platforms', 'Virtual care services', 'Digital therapeutics', 'Wearable health technology', 'Telemedicine software providers', 'Teleconsultation services', 'Telepsychiatry services', ' Remote diagnostics', ' Telemedicine infrastructure providers', ' Telemedicine training and education platforms', ' Telemedicine billing and reimbursement solutions', ' Telemedicine regulatory compliance services', ' Telemedicine cybersecurity solutions'], ['Video game development', 'Esports tournaments and events', 'Gaming hardware manufacturers', 'Esports betting and gambling', 'Streaming platforms for gaming content', 'Virtual reality and augmented reality gaming', 'Gaming accessories and merchandise', 'Esports team management and sponsorship', 'Gaming software and analytics', ' Mobile gaming development', ' Gaming content creation and influencers', ' Esports coaching and training services', ' Online gaming platforms and communities', ' Gaming conventions and expos', ' Esports broadcasting and media coverage']]
# Keywords: [['Microprocessors', 'Memory chips', 'Analog circuits', 'Digital circuits', 'System-on-chip (SoC)', 'Field-programmable gate arrays (FPGAs)', 'Application-specific integrated circuits (ASICs)', 'Semiconductor fabrication', 'Silicon wafer', ' Semiconductor packaging', 'DRAM (Dynamic Random Access Memory)', 'NAND (Negative-AND) Flash', 'Memory chip manufacturers', 'Semiconductor industry', 'Data storage solutions', 'AI (Artificial Intelligence) applications', 'IoT (Internet of Things) devices', 'Market demand for memory chips', 'Supply chain management', ' Emerging technologies in memory chips', 'CPU (Central Processing Unit)', 'Silicon chips', "Moore's Law", 'Semiconductor industry', 'Data processing', 'Integrated circuits', 'Chip design', 'Performance optimization', 'Nanotechnology', ' Artificial intelligence (AI) applications', 'Operational amplifiers', 'Voltage regulators', 'Analog-to-digital converters', 'Signal processing', 'Power management', 'Data acquisition', 'Mixed-signal', 'Low-power design', 'Precision analog', ' Sensor interfaces', 'Lithography', 'Etching', 'Deposition', 'Metrology', 'Wafer handling', 'Cleanroom technology', 'Chemical mechanical polishing', 'Ion implantation', 'Rapid thermal processing', ' Plasma processing', 'Silicon', 'Gallium nitride', 'Silicon carbide', 'III-V compounds', 'Wafer fabrication', 'Thin film deposition', 'Chemical vapor deposition', 'Atomic layer deposition', 'Semiconductor packaging', ' Dielectric materials', 'LED chips', 'Solid-state lighting', 'Energy efficiency', 'Automotive lighting', 'Display technology', 'UV LEDs', 'Smart lighting', 'Horticultural lighting', 'Mini LED', ' OLED lighting', 'Voltage Regulators', 'Power ICs', 'DC-DC Converters', 'Power MOSFETs', 'Energy Efficiency', 'Power Supply Units', 'Battery Management', 'Power Consumption', 'Thermal Management', ' Power Semiconductor Devices', 'RF Power Amplifiers', 'RF Filters', 'RF Transceivers', 'GaN Semiconductors', 'RF Front-End Modules', 'Wireless Communication', '5G Technology', 'IoT Devices', 'Satellite Communication', ' Radar Systems', 'CMOS image sensors', 'CCD image sensors', 'Automotive image sensors', 'Smartphone image sensors', 'Machine vision sensors', '3D image sensors', 'Global image sensors market', 'Sony image sensors', 'Samsung image sensors', ' Emerging image sensor technologies', 'LCD display drivers', 'OLED display drivers', 'TFT display drivers', 'LED display drivers', 'Display driver ICs', 'Touchscreen display drivers', 'Automotive display drivers', 'Mobile display drivers', 'Display driver market', ' Display driver technology', 'Integrated Circuits', 'Embedded Systems', 'IoT Devices', 'Mobile Devices', 'Artificial Intelligence', 'Power Management', 'Wireless Communication', 'Automotive Electronics', 'Consumer Electronics', ' Semiconductor Manufacturing', 'Programmable Logic Devices', 'FPGA Design', 'Hardware Acceleration', 'Reconfigurable Computing', 'FPGA Development Tools', 'High Performance Computing', 'FPGA Prototyping', 'Embedded Systems', 'Digital Signal Processing', ' FPGA Market Trends', 'Light-emitting diodes (LEDs)', 'Photodetectors', 'Optical fibers', 'Laser diodes', 'Optoelectronic sensors', 'Display technologies', 'Photovoltaic cells', 'Fiber optics', 'Semiconductor lasers', ' Optoelectronic devices'], ['Photovoltaic cells', 'Silicon wafers', 'Solar module assembly', 'Thin-film technology', 'Solar panel efficiency', 'Solar panel production', 'Solar energy industry', 'Renewable energy technology', 'Solar panel market', ' Solar panel installation', 'Photovoltaic (PV) inverters', 'Grid-tied inverters', 'Off-grid inverters', 'Microinverters', 'String inverters', 'Power electronics', 'Renewable energy', 'Energy storage', 'Smart grid integration', ' Efficiency optimization', 'Photovoltaic mounting systems', 'Ground mount solar racking', 'Roof mount solar systems', 'Solar panel mounting hardware', 'Solar array racking solutions', 'Fixed tilt solar mounts', 'Tracking solar racking sy ...

# %%
def create_bigrams(lst):
    bigrams = set()
    for sublist in lst:
        for string in sublist:
            words = string.split()
            words=[word.lower().strip() for word in words]
            for i in range(len(words)-1):
                bigrams.add((words[i], words[i+1]))

    return [bigram for bigram in bigrams if 'and' not in bigram and 'for' not in bigram and  'or' not in bigram and 'in' not in bigram]



def compare_bigrams(industry_list, industry_list_golden):
    bigrams_industry = create_bigrams(industry_list)
    bigrams_golden = create_bigrams(industry_list_golden)

    tp = sum(1 for bigram in bigrams_industry if bigram in bigrams_golden)
    fp = sum(1 for bigram in bigrams_industry if bigram not in bigrams_golden)
    fn = sum(1 for bigram in bigrams_golden if bigram not in bigrams_industry)

    score = 5 * tp - fp - fn

    return score, tp, fp, fn

score, tp, fp, fn = compare_bigrams(industry_list, industry_list_golden)
print(f"Score: {score}, TP: {tp}, FP: {fp}, FN: {fn}")
# Out:
# Score: -93, TP: 17, FP: 137, FN: 41

# %%
def compare_bigrams(keywords_list, keywords_list_golden):
    bigrams_industry = create_bigrams(keywords_list)
    bigrams_golden = create_bigrams(keywords_list_golden)

    tp = sum(1 for bigram in bigrams_industry if bigram in bigrams_golden)
    fp = sum(1 for bigram in bigrams_industry if bigram not in bigrams_golden)
    fn = sum(1 for bigram in bigrams_golden if bigram not in bigrams_industry)

    score = 5 * tp - fp - fn

    return score, tp, fp, fn

score, tp, fp, fn = compare_bigrams(keyword_list, Keywords_list_golden)
print(f"Score: {score}, TP: {tp}, FP: {fp}, FN: {fn}")
# Out:
# Score: -591, TP: 87, FP: 841, FN: 185

# %% [markdown]
# Hypothesis 2 : Bert vs Finbert

# %%
# %pip install chromadb
# %pip install pydantic-settings
# Out:
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/dist-packages (0.4.24)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.5.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.110.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.29.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.11.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.62.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.1)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (24.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.18.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-settings in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: pydantic>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings) (2.5.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings) (1.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.3.0->pydantic-settings) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.3.0->pydantic-settings) (2.14.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.3.0->pydantic-settings) (4.11.0)

# %%
from pydantic_settings import BaseSettings
import chromadb
import pandas
import numpy

# %%
import datasets
from datasets import load_dataset
import pandas as pd
dataset = load_dataset("eloukas/edgar-corpus", "year_2020", split="train[:200]")
columns=['cik', 'section_1' ,'section_7']
# Convert to pandas DataFrame
df = pd.DataFrame(dataset)[columns]
df.shape
# Out:
# (5480, 3)

# %%
import datasets
from datasets import load_dataset
import pandas as pd
dataset = load_dataset("eloukas/edgar-corpus", "year_2020", split="train[:100]")
columns=['cik', 'section_1' ,'section_7']
# Convert to pandas DataFrame
df = pd.DataFrame(dataset)[columns]
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# (100, 3)

# %%
df.columns
# Out:
# Index(['cik', 'section_1', 'section_7'], dtype='object')

# %%
documents = df['section_1'].tolist()
companies = df['cik'].tolist()

# %%
df_cik = pd.read_csv('/content/drive/MyDrive/2Stanford/2nlp/project/cik_companies.csv')

# Create a dictionary mapping from CIK keys to company names
cik_to_name = pd.Series(df_cik['Company Name'].values, index=df_cik['Company CIK Key']).to_dict()

# Replace the CIK keys in your list with the corresponding company names
companies = [cik_to_name.get(int(cik), int(cik)) for cik in companies]

# %%
companies
# Out:
# ['COMMUNITY BANCORP /VT',
#  'TEGAL CORP /DE/',
#  'MAXIMUM AWARDS INC',
#  'PAYCHEX INC',
#  'PRISTINE SOLUTIONS INC.',
#  'PACIFIC GREEN TECHNOLOGIES INC.',
#  'MCGRATH RENTCORP',
#  'FORTERRA, INC.',
#  'HOUSTON WIRE & CABLE CO',
#  'AIRBNB, INC.',
#  1711786,
#  'WRAPMAIL, INC.',
#  1816261,
#  1802665,
#  'JOHN BEAN TECHNOLOGIES CORP',
#  'SHAKE SHACK INC.',
#  'WELLS FARGO COMMERCIAL MORTGAGE TRUST 2015-LC22',
#  'FIRST-MID ILLINOIS BANCSHARES INC',
#  1740332,
#  1820160,
#  'POWERMEDCHAIRS',
#  'EMR TECHNOLOGY SOLUTIONS, INC.',
#  'INVESCO PLC/LONDON/',
#  'NOODLES & CO',
#  'FIRST REAL ESTATE INVESTMENT TRUST OF NEW JERSEY',
#  'GREAT AJAX CORP.',
#  'HANOVER INSURANCE GROUP, INC.',
#  'REEL ESTATE SERVICES INC.',
#  'ZIMMER HOLDINGS INC',
#  'FIFTH STREET FINANCE CORP',
#  1753233,
#  'NAVIENT STUDENT LOAN TRUST 2014-5',
#  'STRATTEC SECURITY CORP',
#  1822309,
#  1779474,
#  'SINEXUS INC',
#  'ISLAND RADIO, INC.',
#  'ALEXANDRIA REAL ESTATE EQUITIES INC',
#  1830316,
#  'EBAY INC',
#  'PLASTRON ACQUISITION CORP II',
#  'CENTRAL ILLINOIS PUBLIC SERVICE CO',
#  'AZZ INC',
#  'SIERRA CONCEPTS, INC.',
#  'EARLY EQUINE INC',
#  'HOLLY ENERGY PARTNERS LP',
#  'SCANDIUM INTERNATIONAL MINING CORP.',
#  'SPORTS ASYLUM, INC.',
#  'LYDALL INC /DE/',
#  'SEYCHELLE ENVIRONMENTAL TECHNOLOGIES INC /CA',
#  'HOLLYFRONTIER CORP',
#  'TUCOWS INC /PA/',
#  "LANDS' END, INC.",
#  'FERRO CORP',
#  'FULGENT GENETICS, INC.',
#  1710765,
#  'CITIZENS COMMUNITY BANCORP INC.',
#  'SOCIAL LIFE NETWORK, INC.',
#  'GRIFFIN LAND & NURSERIES INC',
#  'ROCKY HOLDING, INC.',
#  'DIVIDEND CAPITAL TOTAL REALTY TRUST INC.',
#  'J.P. MORGAN CHASE COMMERCIAL MORTGAGE SECURITIES TRUST 2013-C13',
#  1759008,
#  'MORGAN STANLEY BANK OF AMERICA MERRILL LYNCH TRUST 2013-C8',
#  'LINE UP ADVERTISEMENT, INC.',
#  'CARRIAGE SERVICES INC',
#  1774170,
#  'KETDARINA CORP',
#  'SUSSER PETROLEUM PARTNERS LP',
#  'KIMBALL INTERNATIONAL INC',
#  'VIANET TECHNOLOGY GROUP LTD',
#  'CITIGROUP COMMERCIAL MORTGAGE TRUST 2015-P1',
#  'AMERICAN WATER WORKS COMPANY, INC.',
#  1807011,
#  'NEURONETICS, INC.',
#  'F&M BANK CORP',
#  'GEX MANAGEMENT, INC.',
#  'KRONOS WORLDWIDE INC',
#  'PRIME RESOURCE INC',
#  1823776,
#  'AVALON HOLDINGS CORP',
#  'ARCHER DANIELS MIDLAND CO',
#  'GRANITE FALLS ENERGY, LLC',
#  'DYNAVAX TECHNOLOGIES CORP',
#  'AUTOMATIC DATA PROCESSING INC',
#  'PREVENTION INSURANCE COM',
#  'HECLA MINING CO/DE/',
#  1812528,
#  'SOUND FINANCIAL BANCORP, INC.',
#  'COLUMBIA SPORTSWEAR CO',
#  1825437,
#  'EARTH LIFE SCIENCES INC',
#  1708331,
#  'ASSURED GUARANTY LTD',
#  'PALANTIR TECHNOLOGIES INC',
#  'ATEL 16, LLC',
#  'ALR TECHNOLOGIES INC',
#  'WELLS FARGO COMMERCIAL MORTGAGE TRUST 2017-RC1',
#  'NOVATION COMPANIES, INC.',
#  'NBH INC']

# %%
# %pip install transformers
# %pip install torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import pandas as pd
from transformers import BertModel, BertTokenizer
import torch

# %%
from chromadb.config import Settings
chroma_client = chromadb.PersistentClient(path="/content/drive/MyDrive/2Stanford/2nlp/project/chromadb")

# %%
chroma_client.delete_collection(name="sec_fillings_Bert")

# Load pre-trained model tokenizer (vocabulary)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
# Load pre-trained model (weights)
model = BertModel.from_pretrained('bert-base-uncased')

# %%
class BERTEmbeddingFunction:
    def __init__(self):
        # Load pre-trained model tokenizer (vocabulary)
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

        # Load pre-trained model (weights)
        self.model = BertModel.from_pretrained('bert-base-uncased')

    def __call__(self, input):
        # Tokenize input
        encoded_input = self.tokenizer(input, return_tensors='pt', padding=True, truncation=True, max_length=512)

        # Predict hidden states features for each layer
        with torch.no_grad():
            model_output = self.model(**encoded_input)

        # You can access the embeddings via model_output.last_hidden_state
        embeddings = model_output.last_hidden_state

        # Average the token embeddings to get a single vector
        averaged_embeddings = torch.mean(embeddings, dim=1)

        # Convert tensor to numpy array and then to list
        return averaged_embeddings.numpy().tolist()

# %%
def split_into_chunks(text, chunk_size=1000):
    text=str(text)
    return [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

chunks = []
metadatas = []
for document, company in zip(documents, companies):
    document_chunks = split_into_chunks(document)
    for i, chunk in enumerate(document_chunks):
        chunks.append(chunk)
        metadatas.append({'id': f"{company}_{i}", 'company': company})

# %%
bert_ef = BERTEmbeddingFunction()
sec_collection = chroma_client.get_or_create_collection(name="sec_fillings_Bert",embedding_function=bert_ef)

# %%
# %%time
sec_collection.add(
    documents=chunks,
    metadatas=metadatas,
    ids=[metadata['id'] for metadata in metadatas])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# NameError: name 'sec_collection' is not defined

# %%
class BERTQueryFunction:
    def __init__(self):
        # Load pre-trained model tokenizer (vocabulary)
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

        # Load pre-trained model (weights)
        self.model = BertModel.from_pretrained('bert-base-uncased')

    def __call__(self, query):
        # Tokenize input
        encoded_query = self.tokenizer(query, return_tensors='pt', padding=True, truncation=True, max_length=512)

        # Predict hidden states features for each layer
        with torch.no_grad():
            model_output = self.model(**encoded_query)

        # You can access the embeddings via model_output.last_hidden_state
        embeddings = model_output.last_hidden_state

        # Average the token embeddings to get a single vector
        averaged_embeddings = torch.mean(embeddings, dim=1)

        # Convert tensor to numpy array and then to list
        return averaged_embeddings.numpy().tolist()

# %%
# Instantiate the BERTQueryFunction
bert_qf = BERTQueryFunction()

# Use the BERTQueryFunction to convert the query into a BERT embedding
query_embedding = bert_qf("What are the companies associated with Next Generation Internet ?")

# Use the chroma_client to retrieve the most similar documents from the database
results = sec_collection.query(query_embedding, n_results=10)

results
# Out:
# {'ids': [['1386049_38',
#    'REEL ESTATE SERVICES INC._38',
#    '909494_26',
#    'TUCOWS INC /PA/_26',
#    '55772_22',
#    'KIMBALL INTERNATIONAL INC_22',
#    '1604778_2',
#    'ROCKY HOLDING, INC._2',
#    '1575659_29',
#    'POWERMEDCHAIRS_29']],
#  'distances': [[39.053680419921875,
#    39.053680419921875,
#    39.97312927246094,
#    39.97312927246094,
#    40.19363021850586,
#    40.19363021850586,
#    41.81492614746094,
#    41.81492614746094,
#    42.416343688964844,
#    42.416343688964844]],
#  'metadatas': [[{'company': '1386049', 'id': '1386049_38'},
#    {'company': 'REEL ESTATE SERVICES INC.',
#     'id': 'REEL ESTATE SERVICES INC._38'},
#    {'company': '909494', 'id': '909494_26'},
#    {'company': 'TUCOWS INC /PA/', 'id': 'TUCOWS INC /PA/_26'},
#    {'company': '55772', 'id': '55772_22'},
#    {'company': 'KIMBALL INTERNATIONAL INC',
#     'id': 'KIMBALL INTERNATIONAL INC_22'},
#    {'company': '1604778', 'id': '1604778_2'},
#    {'company': 'ROCKY HOLDING, INC.', 'id': 'ROCKY HOLDING, INC._2'},
#    {'company': '1575659', 'id': '1575659_29'},
#    {'company': 'POWERMEDCHAIRS', 'id': 'POWERMEDCHAIRS_29'}]],
#  'embeddings': None,
#  'documents': [['d) solutions or they may have a range of information management solutions. Given the markets in which we plan to operate and the products and services we plan to offer, we believe our top competitors to be Clarabridge, Confirmit, InMoment, MartizCX, Medallia, NICE, Qualtrics, Satmetrix Systems, SMG and Verint Systems.\nWe believe that many of our competitors in the IMT&S industry would be small, and of those, many are non-employing firms. Companies in the industry in which we intend to operate offer a broad range of product and services tailored to different markets. This mobility has allowed smaller firms to dominate the industry composition, as they tend to provide services to a specific niche market and/or within a specific geographic region. Despite their prevalence, smaller firms contribute only a small percentage of industry revenue. The bulk of revenue is generated by several high-profile global corporations, such as IBM, Hewlett-Packard, EMC Corporation, SAS, and Accenture. Larg',
#    'd) solutions or they may have a range of information management solutions. Given the markets in which we plan to operate and the products and services we plan to offer, we believe our top competitors to be Clarabridge, Confirmit, InMoment, MartizCX, Medallia, NICE, Qualtrics, Satmetrix Systems, SMG and Verint Systems.\nWe believe that many of our competitors in the IMT&S industry would be small, and of those, many are non-employing firms. Companies in the industry in which we intend to operate offer a broad range of product and services tailored to different markets. This mobility has allowed smaller firms to dominate the industry composition, as they tend to provide services to a specific niche market and/or within a specific geographic region. Despite their prevalence, smaller firms contribute only a small percentage of industry revenue. The bulk of revenue is generated by several high-profile global corporations, such as IBM, Hewlett-Packard, EMC Corporation, SAS, and Accenture. Larg',
#    ' support non-core applications in-house.\nSeasonality\nDuring the summer months and certain other times of the year, such as major holidays, Internet usage often declines. As a result, some of our services (such as OpenSRS, eNom, Ascio, and Hover) may experience reduced demand during these times. For example, our experience shows that new domain registrations decline during the summer months and around the year-end holidays.\nCompetition\nOur competitors may be divided into the following groups:\n•\nUS Broadband providers such as AT&T, Comcast, Verizon and CenturyLink, who primarily compete with Ting Internet Services.\n•\nRetail-oriented domain registrars, such as GoDaddy and Web.com who compete with our Reseller customers in wholesale domain services and with Hover.\n•\nWholesale-oriented domain registrars, such as GoDaddy, who market services to resellers such as our customers.\n•\nWholesale Email Service providers, such as Google, Microsoft, Bluetie and MailTrust.\nWe expect to continue to expe',
#    ' support non-core applications in-house.\nSeasonality\nDuring the summer months and certain other times of the year, such as major holidays, Internet usage often declines. As a result, some of our services (such as OpenSRS, eNom, Ascio, and Hover) may experience reduced demand during these times. For example, our experience shows that new domain registrations decline during the summer months and around the year-end holidays.\nCompetition\nOur competitors may be divided into the following groups:\n•\nUS Broadband providers such as AT&T, Comcast, Verizon and CenturyLink, who primarily compete with Ting Internet Services.\n•\nRetail-oriented domain registrars, such as GoDaddy and Web.com who compete with our Reseller customers in wholesale domain services and with Hover.\n•\nWholesale-oriented domain registrars, such as GoDaddy, who market services to resellers such as our customers.\n•\nWholesale Email Service providers, such as Google, Microsoft, Bluetie and MailTrust.\nWe expect to continue to expe',
#    '. Disruptions have eased but if COVID-19 impacts worsen, cost and availability of raw materials could be impacted.\nOrder Backlog\nThe aggregate sales price of products pursuant to open orders, which may be canceled by the customer, was as follows:\nThe open orders as of June 30, 2020 are expected to be filled within fiscal year 2021, with $90 million expected to be filled during our first quarter of fiscal year 2021. The decline in the order backlog at June 30, 2020 was driven by the COVID-19 pandemic. Open orders may not be indicative of future sales trends.\nIntellectual Property\nIn connection with our business operations, we hold both trademarks and patents in various countries and continuously have additional pending trademarks and patents. The intellectual property which we believe to be the most significant to the\nCompany includes: Kimball, National, D’style, David Edward, Etc.(pending), Fringe, Waveworks, Xsite, Narrate, Pairings, Respitality, and Allan Copley Designs, which are al',
#    '. Disruptions have eased but if COVID-19 impacts worsen, cost and availability of raw materials could be impacted.\nOrder Backlog\nThe aggregate sales price of products pursuant to open orders, which may be canceled by the customer, was as follows:\nThe open orders as of June 30, 2020 are expected to be filled within fiscal year 2021, with $90 million expected to be filled during our first quarter of fiscal year 2021. The decline in the order backlog at June 30, 2020 was driven by the COVID-19 pandemic. Open orders may not be indicative of future sales trends.\nIntellectual Property\nIn connection with our business operations, we hold both trademarks and patents in various countries and continuously have additional pending trademarks and patents. The intellectual property which we believe to be the most significant to the\nCompany includes: Kimball, National, D’style, David Edward, Etc.(pending), Fringe, Waveworks, Xsite, Narrate, Pairings, Respitality, and Allan Copley Designs, which are al',
#    'hanical system ("MEMS") technology for RF switching applications;\n•\nCustom MMIC Design Services, Inc. ("Custom MMIC"), a fabless provider of gallium arsenide ("GaAs") and gallium nitride ("GaN") monolithic microwave integrated circuits ("MMICs") for defense and aerospace applications; and,\n•\nDecawave Limited ("Decawave"), a leader in UWB technology and provider of UWB solutions for mobile, automotive and IoT applications.\nQorvo was incorporated in Delaware in 2013. Our principal executive office is located at 7628 Thorndike Road, Greensboro, North Carolina 27409-9421 and our telephone number is (336) 664-1233.\nIndustry Trends\nThere is growing global demand for ubiquitous, always-on connectivity. Total mobile data traffic continues to grow as smartphones, laptops, and other mobile devices are used increasingly to access the internet, stream videos, interact on social media and access other services. 5G is expected to enhance how we connect, communicate and transact business. 5G will imp',
#    'hanical system ("MEMS") technology for RF switching applications;\n•\nCustom MMIC Design Services, Inc. ("Custom MMIC"), a fabless provider of gallium arsenide ("GaAs") and gallium nitride ("GaN") monolithic microwave integrated circuits ("MMICs") for defense and aerospace applications; and,\n•\nDecawave Limited ("Decawave"), a leader in UWB technology and provider of UWB solutions for mobile, automotive and IoT applications.\nQorvo was incorporated in Delaware in 2013. Our principal executive office is located at 7628 Thorndike Road, Greensboro, North Carolina 27409-9421 and our telephone number is (336) 664-1233.\nIndustry Trends\nThere is growing global demand for ubiquitous, always-on connectivity. Total mobile data traffic continues to grow as smartphones, laptops, and other mobile devices are used increasingly to access the internet, stream videos, interact on social media and access other services. 5G is expected to enhance how we connect, communicate and transact business. 5G will imp',
#    'delivery method for cannabidiols. The Company competes in the market with other pMDI makers and other producers of alternative cannabidiol delivery systems, such as oral, nasal, or topical.\nCBD has driven the hemp boom for a decade now, and that trend is expected to continue for years to come, according to Nielsen Global Connect, a division of The Nielsen Co. which focuses on data for manufacturers and retailers. The rise is driven by increasing acceptance of CBD as a dietary supplement, especially as a global pandemic and economic stressors have consumers reaching for products thought to boost wellness and immunity and enhance relaxation. Nielsen projects that hemp’s 2020 sales of $1.9 billion will balloon to $6.9 billion in 2025, a threefold increase over five years. Inhalable CBD (such as the MDI offered by the Company) is also expected to show significant growth, from $267 million in 2020 to $793 million in 2025 (an increase of 197%).\nIntellectual Property\nOur intellectual property',
#    'delivery method for cannabidiols. The Company competes in the market with other pMDI makers and other producers of alternative cannabidiol delivery systems, such as oral, nasal, or topical.\nCBD has driven the hemp boom for a decade now, and that trend is expected to continue for years to come, according to Nielsen Global Connect, a division of The Nielsen Co. which focuses on data for manufacturers and retailers. The rise is driven by increasing acceptance of CBD as a dietary supplement, especially as a global pandemic and economic stressors have consumers reaching for products thought to boost wellness and immunity and enhance relaxation. Nielsen projects that hemp’s 2020 sales of $1.9 billion will balloon to $6.9 billion in 2025, a threefold increase over five years. Inhalable CBD (such as the MDI offered by the Company) is also expected to show significant growth, from $267 million in 2020 to $793 million in 2025 (an increase of 197%).\nIntellectual Property\nOur intellectual property']],
#  'uris': None,
#  'data': None}

# %% [markdown]
# Finbert

# %%
from transformers import AutoTokenizer, AutoModel

class FinBERTEmbeddingFunction:
    def __init__(self):
        # Load pre-trained model tokenizer (vocabulary)
        self.tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')

        # Load pre-trained model (weights)
        self.model = AutoModel.from_pretrained('ProsusAI/finbert')

    def __call__(self, input):
        # Tokenize input
        encoded_input = self.tokenizer(input, return_tensors='pt', padding=True, truncation=True, max_length=512)

        # Predict hidden states features for each layer
        with torch.no_grad():
            model_output = self.model(**encoded_input)

        # You can access the embeddings via model_output.last_hidden_state
        embeddings = model_output.last_hidden_state

        # Average the token embeddings to get a single vector
        averaged_embeddings = torch.mean(embeddings, dim=1)

        # Convert tensor to numpy array and then to list
        return averaged_embeddings.numpy().tolist()


class FinBERTQueryFunction:
    def __init__(self):
        # Load pre-trained model tokenizer (vocabulary)
        self.tokenizer = AutoTokenizer.from_pretrained('ProsusAI/finbert')

        # Load pre-trained model (weights)
        self.model = AutoModel.from_pretrained('ProsusAI/finbert')

    def __call__(self, query):
        # Tokenize input
        encoded_query = self.tokenizer(query, return_tensors='pt', padding=True, truncation=True, max_length=512)

        # Predict hidden states features for each layer
        with torch.no_grad():
            model_output = self.model(**encoded_query)

        # You can access the embeddings via model_output.last_hidden_state
        embeddings = model_output.last_hidden_state

        # Average the token embeddings to get a single vector
        averaged_embeddings = torch.mean(embeddings, dim=1)

        # Convert tensor to numpy array and then to list
        return averaged_embeddings.numpy().tolist()

# %%
# Instantiate the FinBERTEmbeddingFunction
finbert_ef = FinBERTEmbeddingFunction()

# %%
chroma_client.delete_collection(name="sec_fillings_finbert")

# %%
sec_collection_finbert = chroma_client.get_or_create_collection(name="sec_fillings_finbert",embedding_function=finbert_ef)

# %%
# %%time
sec_collection_finbert.add(
    documents=chunks,
    metadatas=metadatas,
    ids=[metadata['id'] for metadata in metadatas])
# Out:
# CPU times: user 44min 25s, sys: 24min 3s, total: 1h 8min 28s
# Wall time: 14min 14s

# %%
# Instantiate the FinBERTQueryFunction
finbert_qf = FinBERTQueryFunction()

# Use the FinBERTQueryFunction to convert the query into a FinBERT embedding
query_embedding = finbert_qf("What are the companies associated with Next Generation Internet ?")

# Use the chroma_client to retrieve the most similar documents from the database
results = sec_collection_finbert.query(query_embedding, n_results=10)

results
# Out:
# {'ids': [['NBH INC_116',
#    '1708331_27',
#    "LANDS' END, INC._3",
#    'VIANET TECHNOLOGY GROUP LTD_67',
#    '1825437_29',
#    'FERRO CORP_0',
#    'PRIME RESOURCE INC_63',
#    'SIERRA CONCEPTS, INC._29',
#    '1708331_25',
#    'ZIMMER HOLDINGS INC_49']],
#  'distances': [[72.51307082630936,
#    73.04689025878906,
#    75.30615234375,
#    75.7044448852539,
#    76.47148895263672,
#    77.24732971191406,
#    77.5732421875,
#    77.61244201660156,
#    77.82809448242188,
#    78.21311950683594]],
#  'metadatas': [[{'company': 'NBH INC', 'id': 'NBH INC_116'},
#    {'company': 1708331, 'id': '1708331_27'},
#    {'company': "LANDS' END, INC.", 'id': "LANDS' END, INC._3"},
#    {'company': 'VIANET TECHNOLOGY GROUP LTD',
#     'id': 'VIANET TECHNOLOGY GROUP LTD_67'},
#    {'company': 1825437, 'id': '1825437_29'},
#    {'company': 'FERRO CORP', 'id': 'FERRO CORP_0'},
#    {'company': 'PRIME RESOURCE INC', 'id': 'PRIME RESOURCE INC_63'},
#    {'company': 'SIERRA CONCEPTS, INC.', 'id': 'SIERRA CONCEPTS, INC._29'},
#    {'company': 1708331, 'id': '1708331_25'},
#    {'company': 'ZIMMER HOLDINGS INC', 'id': 'ZIMMER HOLDINGS INC_49'}]],
#  'embeddings': None,
#  'documents': [['ic and emerging brands. Berkshire subsidiaries also own a 50% joint venture interest in Berkadia Commercial Mortgage LLC (“Berkadia”), a 38.6% interest in Pilot Travel Centers LLC (“Pilot”) and a 50% joint venture interest in Electric Transmission Texas, LLC (“ETT”). Information concerning these investments is included in Note 5 to Berkshire’s Consolidated Financial Statements.\nBerkshire maintains a website (http://www.berkshirehathaway.com) where its annual reports, certain corporate governance documents, press releases, interim shareholder reports and links to its subsidiaries’ websites can be found. Berkshire’s periodic reports filed with the SEC, which include Form 10-K, Form 10-Q, Form 8-K and amendments thereto, may be accessed by the public free of charge from the SEC and through Berkshire. Electronic copies of these reports can be accessed at the SEC’s website (http://www.sec.gov) and indirectly through Berkshire’s website (http://www.berkshirehathaway.com). Copies of these rep',
#    'atent Nos. 8,278,277 (expires August 16, 2030) and 8,920,819 (expires April 29, 2029), a Canadian patent (expires March 1, 2030) and a pending European application (which would expire March 1, 2030). This family covers lipophilic derivatives of hydrophilic drugs comprising a hydrophilic drug and a cleavable linker as well as methods of treatment using these compositions. In particular the patents relate to compositions of a lipophilic derivative of the hydrophilic neuropeptide Leucine [5]-Enkephalin and an amphiphile compound, where the derivative includes a lipophilic linker attached to the side chain oxygen of the tyrosine in the Leucine [5]-Enkephalin, and where the amphiphile compound is quaternary palmitoyl glycol chitosan (GCPQ).\nPatent Family 4 includes US Patent No. 10,213,474 (expires November 3, 2034), a Japanese patent (expires November 3, 2034), a European patent (expires November 3, 2034) and a pending Canadian patent application (which would expire November 3, 2034). The ',
#    'founder\'s motto as one of our guiding principles: "Take care of the customer, take care of the employee and the rest will take care of itself."\nLands’ End seeks to provide a common customer experience regardless of whether they are interacting with us on our company websites, third party marketplaces, at Company Operated stores or other distribution channels.\nWe have one external reportable segment and identify our operating segments according to how our business activities are managed and evaluated. Our operating segments consist of U.S. eCommerce, Retail, Lands\' End Outfitters ("Outfitters"), Europe eCommerce and Japan eCommerce. We have determined that each of our operating segments share similar economic and other qualitative characteristics, and therefore the results of our operating segments are aggregated into one external reportable segment.\nLands\' End\'s product channels are eCommerce, Retail and Outfitters. eCommerce offers products through the Company\'s eCommerce websites, th',
#    'organized under the laws of Republic of Malta on April 4, 2019 for future business opportunities in Europe, Newgioco Colombia SAS, a company organized under the laws of Colombia on November 26, 2019 to develop our operations through South and Central America, and Elys Gameboard Technologies a limited liability company organized in the State of Delaware on May 28, 2020 to develop our U.S. business operations. Our prior subsidiaries included, Rifa Srl from January 1, 2015 that was amalgamated into Multigioco with effect on January 20, 2020 and Naos Holding Limited a non-operating holding company from January 30, 2019 that was discontinued with effect on December 31, 2019. Our telephone number is 1-628-258-5148. Our corporate website address is www.elysgame.com. The information contained on our website is not incorporated by reference into this Annual Report, and you should not consider any information contained on, or that can be accessed through, our website as part of this Annual Repor',
#    'd party with respect to raising any additional funds through the sale of securities or otherwise.\nSources of Target Businesses\nTarget business candidates are brought to our attention from various unaffiliated sources, including investment bankers and investment professionals. Target businesses may be brought to our attention by such unaffiliated sources as a result of being solicited by us by calls or mailings. These sources may also introduce us to target businesses in which they think we may be interested on an unsolicited basis, since many of these sources will have read our public filings and know what types of businesses we are targeting. Our officers and directors, as well as our sponsor and their affiliates, may also bring to our attention target business candidates that they become aware of through their business contacts as a result of formal or informal inquiries or discussions they may have, as well as attending trade shows or conventions. In addition, we expect to receive a',
#    'Item 1 - Business\nHistory, Organization and Products\nFerro Corporation is a leading producer of specialty materials that are sold to a broad range of manufacturers who, in turn, make products for many end-use markets. When we use the terms “Ferro,” “we,” “us” or “the Company,” we are referring to Ferro Corporation and its subsidiaries unless indicated otherwise.\nFerro’s products fall into two general categories: functional coatings, which perform specific functions in the end products and manufacturing processes of our customers; and color solutions, which provide performance and aesthetic characteristics to our customers’ products. Our products are manufactured in approximately 48 facilities around the world. They include frits, porcelain and other glass enamels, glazes, stains, decorating colors, pigments, inks, polishing materials, dielectrics, electronic glasses, and other specialty coatings.\nFerro develops and delivers innovative products to our customers based on our strengths in',
#    'inical trials, including negative or ambiguous results as well as positive findings, together with detailed information relating to the product’s chemistry, manufacturing, controls and proposed labeling, among other things. Data can come from company-sponsored clinical trials intended to test the safety and effectiveness of a use of a product, or from a number of alternative sources, including studies initiated by investigators that meet GCP requirements.\nDuring the development of a new drug, sponsors are given opportunities to meet with the FDA at certain points. These points may be prior to submission of an IND, at the end of Phase II clinical trials, and before an NDA is submitted. Meetings at other times may be requested. These meetings can provide an opportunity for the sponsor to share information about the data gathered to date, for the FDA to provide advice and for the sponsor and the FDA to reach agreement on the next phase of development. Sponsors typically use the end-of-Pha',
#    'lable, free of charge, our Annual Reports on Form 10-K, Quarterly Reports on Form 10-Q, Current Reports on Form 8-K, and amendments to those reports as soon as reasonably practicable after we electronically file them with or furnish them to the SEC. The SEC maintains an Internet site that contains reports, proxy and information statements and other information regarding issuers, such as us, that file electronically with the SEC at www.sec.gov.\nWe webcast our earnings calls and certain events we participate in with members of the investment community on our investor relations website. Additionally, we provide notifications of news or announcements regarding our financial performance, including SEC filings, investor events and press and earnings releases as part of the investor relations section of our website. Further corporate governance materials, including our Corporate Governance Guidelines, charters of our Board Committees and our Code of Business Ethics and Conduct, are also avail',
#    'n aerosol dispenser containing the formulation.\nProbudur\nThe product candidate is covered by US Patent No. 9,713,591 (expires July 24, 2030) as well as a European patent (expires October 11, 2029) and a Chinese patent (expires October 11, 2029). There is also a pending US application which is a continuation of US Patent No. 9,713,591 and for which a notice of allowance has been received and the issue fee paid. The patent contains composition claims to pharmaceutical compositions having an external storage solution containing an active pharmaceutical ingredient and particles of liposomes embedded in a polymeric matrix contained within the storage solution.\nEnvelta\nThe product candidate is covered by the following patent families which protect the chemistry of the MET polymer and its use in pharmaceutical products: Patent Family 1 includes US Patent No. 7,741,474 (expires March 18, 2026), and a Japanese Patent, Canadian Patent and European Patent (all which expire September 22,2023). Thi',
#    ' website in the “Investor Relations” section, which may be accessed from our homepage at www.zimmerbiomet.com or directly at https://investor.zimmerbiomet.com. We use this website as a means of disclosing material, non-public information and for complying with our disclosure obligations under Regulation FD. Accordingly, investors should monitor the Investor Relations section of our website, in addition to following our press releases, SEC filings, public conference calls, presentations and webcasts. Our goal is to maintain the Investor Relations website as a portal through which investors can easily find or navigate to pertinent information about us, free of charge, including:\n•\nour Annual Reports on Form 10-K, Quarterly Reports on Form 10-Q, Current Reports on Form 8-K and amendments to those reports filed or furnished pursuant to Section 13(a) or 15(d) of the Securities Exchange Act of 1934, as amended (“Exchange Act”), as soon as reasonably practicable after we electronically file t']],
#  'uris': None,
#  'data': None}
